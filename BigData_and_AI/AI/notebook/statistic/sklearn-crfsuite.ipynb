# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
from itertools import chain

import nltk
import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

# %%
nltk.download('conll2002')
nltk.corpus.conll2007.fileids()
# Out:
# [nltk_data] Downloading package conll2002 to /home/zhouh/nltk_data...
# [nltk_data]   Package conll2002 is already up-to-date!
# ['esp.test', 'esp.train', 'eus.test', 'eus.train']

# %% [markdown]
# ## Let's use CoNLL 2002 data to build a NER system
#
# CoNLL2002 corpus is available in NLTK. We use Spanish data.

# %%
nltk.corpus.conll2002.fileids()
# Out:
# ['esp.testa', 'esp.testb', 'esp.train', 'ned.testa', 'ned.testb', 'ned.train']

# %%
train_sents = list(nltk.corpus.conll2002.iob_sents('esp.train'))
test_sents = list(nltk.corpus.conll2002.iob_sents('esp.testb'))

# %%
train_sents[0]
# Out:
# [('Melbourne', 'NP', 'B-LOC'),
#  ('(', 'Fpa', 'O'),
#  ('Australia', 'NP', 'B-LOC'),
#  (')', 'Fpt', 'O'),
#  (',', 'Fc', 'O'),
#  ('25', 'Z', 'O'),
#  ('may', 'NC', 'O'),
#  ('(', 'Fpa', 'O'),
#  ('EFE', 'NC', 'B-ORG'),
#  (')', 'Fpt', 'O'),
#  ('.', 'Fp', 'O')]

# %% [markdown]
# ## Features
#
# Next, define some features. In this example we use word identity, word suffix, word shape and word POS tag; also, some information from nearby words is used.
#
# This makes a simple baseline, but you certainly can add and remove some features to get (much?) better results - experiment with it.
#
# sklearn-crfsuite (and python-crfsuite) supports several feature formats; here we use feature dicts.

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    
    features = {
        'bias': 1.0,  # proportion of label
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],        
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True
        
    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True
                
    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %%
word_to_ix = {}
for sentence in train_sents:
    for token, postag, label in sentence:
        if token not in word_to_ix:
            word_to_ix[token] = len(word_to_ix)
            
word_to_ix
# Out:
# {'Melbourne': 0,
#  '(': 1,
#  'Australia': 2,
#  ')': 3,
#  ',': 4,
#  '25': 5,
#  'may': 6,
#  'EFE': 7,
#  '.': 8,
#  '-': 9,
#  'El': 10,
#  'Abogado': 11,
#  'General': 12,
#  'del': 13,
#  'Estado': 14,
#  'Daryl': 15,
#  'Williams': 16,
#  'subrayó': 17,
#  'hoy': 18,
#  'la': 19,
#  'necesidad': 20,
#  'de': 21,
#  'tomar': 22,
#  'medidas': 23,
#  'para': 24,
#  'proteger': 25,
#  'al': 26,
#  'sistema': 27,
#  'judicial': 28,
#  'australiano': 29,
#  'frente': 30,
#  'a': 31,
#  'una': 32,
#  'página': 33,
#  'internet': 34,
#  'que': 35,
#  'imposibilita': 36,
#  'el': 37,
#  'cumplimiento': 38,
#  'los': 39,
#  'principios': 40,
#  'básicos': 41,
#  'Ley': 42,
#  'La': 43,
#  'petición': 44,
#  'tiene': 45,
#  'lugar': 46,
#  'después': 47,
#  'un': 48,
#  'juez': 49,
#  'Tribunal': 50,
#  'Supremo': 51,
#  'estado': 52,
#  'Victoria': 53,
#  'se': 54,
#  'viera': 55,
#  'forzado': 56,
#  'disolver': 57,
#  'jurado': 58,
#  'popular': 59,
#  'y': 60,
#  'suspender': 61,
#  'proceso': 62,
#  'ante': 63,
#  'argumento': 64,
#  'defensa': 65,
#  'las': 66,
#  'personas': 67,
#  'lo': 68,
#  'componían': 69,
#  'podían': 70,
#  'haber': 71,
#  'obtenido': 72,
#  'información': 73,
#  'sobre': 74,
#  'acusado': 75,
#  'través': 76,
#  'CrimeNet': 77,
#  'Esta': 78,
#  'web': 79,
#  'lleva': 80,
#  'mes': 81,
#  'existencia': 82,
#  'tiempo': 83,
#  'en': 84,
#  'ha': 85,
#  'sido': 86,
#  'visitada': 87,
#  'más': 88,
#  'millón': 89,
#  'ocasiones': 90,
#  'facilita': 91,
#  'miles': 92,
#  'crímenes': 93,
#  'criminales': 94,
#  'ya': 95,
#  'enjuiciados': 96,
#  'o': 97,
#  'aún': 98,
#  'perseguidos': 99,
#  'datos': 100,
#  'salen': 101,
#  'artículos': 102,
#  'periódicos': 103,
#  'archivos': 104,
#  'judiciales': 105,
#  'Por': 106,
#  'su': 107,
#  'parte': 108,
#  'Rob': 109,
#  'Hulls': 110,
#  'indicó': 111,
#  'no': 112,
#  'hay': 113,
#  'nadie': 114,
#  'controle': 115,
#  'informaciones': 116,
#  'contenidas': 117,
#  'son': 118,
#  'veraces': 119,
#  'señaló': 120,
#  'jurídico': 121,
#  'Commonwealth': 122,
#  'basa': 123,
#  'justicia': 124,
#  'australiana': 125,
#  'es': 126,
#  'fundamental': 127,
#  'persona': 128,
#  'sea': 129,
#  'juzgada': 130,
#  'únicamente': 131,
#  'teniendo': 132,
#  'cuenta': 133,
#  'pruebas': 134,
#  'presentadas': 135,
#  'citada': 136,
#  'considera': 137,
#  'también': 138,
#  'causa': 139,
#  'conclusión': 140,
#  'prematura': 141,
#  'caso': 142,
#  'asesinato': 143,
#  'juzgado': 144,
#  'recientemente': 145,
#  'ciudad': 146,
#  'capital': 147,
#  'Santander': 148,
#  'Izquierda': 149,
#  'Unida': 150,
#  'presentó': 151,
#  'nuevo': 152,
#  'boletín': 153,
#  'trimestral': 154,
#  '"': 155,
#  'Ciudad': 156,
#  'publicación': 157,
#  'distribuirán': 158,
#  '10.000': 159,
#  'ejemplares': 160,
#  'preferentemente': 161,
#  'barrios': 162,
#  'municipio': 163,
#  'donde': 164,
#  'colación': 165,
#  'con': 166,
#  'mayor': 167,
#  'respaldo': 168,
#  'ciudadano': 169,
#  'portavoz': 170,
#  'Consejo': 171,
#  'Político': 172,
#  'Municipal': 173,
#  'IU': 174,
#  'Ernesto': 175,
#  'Gómez': 176,
#  'Hera': 177,
#  'explicó': 178,
#  'conferencia': 179,
#  'prensa': 180,
#  'este': 181,
#  'persigue': 182,
#  'informar': 183,
#  'abrir': 184,
#  'espacios': 185,
#  'debate': 186,
#  'servir': 187,
#  'como': 188,
#  'semilla': 189,
#  'movilización': 190,
#  'política': 191,
#  'comentó': 192,
#  'contenidos': 193,
#  'responden': 194,
#  'programa': 195,
#  'él': 196,
#  'encabezó': 197,
#  'candidato': 198,
#  'elecciones': 199,
#  'municipales': 200,
#  '1999': 201,
#  'perdió': 202,
#  'representación': 203,
#  'Ayuntamiento': 204,
#  'confió': 205,
#  'difusión': 206,
#  'amplia': 207,
#  'vez': 208,
#  'coalición': 209,
#  'resuelva': 210,
#  'crisis': 211,
#  'económica': 212,
#  'momento': 213,
#  'será': 214,
#  'repartida': 215,
#  'forma': 216,
#  'preferencial': 217,
#  'electores': 218,
#  'entre': 219,
#  'municipal': 220,
#  'citó': 221,
#  'ladera': 222,
#  'norte': 223,
#  'calle': 224,
#  'Alta': 225,
#  'Cazoña': 226,
#  'zona': 227,
#  'comprendida': 228,
#  'calles': 229,
#  'Castilla': 230,
#  'Hermida': 231,
#  'compuesto': 232,
#  'por': 233,
#  'dos': 234,
#  'folios': 235,
#  'plegados': 236,
#  'mitad': 237,
#  'sale': 238,
#  'primer': 239,
#  'número': 240,
#  'criticando': 241,
#  'obras': 242,
#  'construcción': 243,
#  'aparcamientos': 244,
#  'subterráneos': 245,
#  'molestias': 246,
#  'están': 247,
#  'causando': 248,
#  'vecinos': 249,
#  'modo': 250,
#  'explotarán': 251,
#  'PP': 252,
#  'hacer': 253,
#  'dinero': 254,
#  'absolutamente': 255,
#  'todo': 256,
#  'ese': 257,
#  'distribuya': 258,
#  'sus': 259,
#  'amigos': 260,
#  'convertido': 261,
#  'trampa': 262,
#  'llena': 263,
#  'agujeros': 264,
#  'cuando': 265,
#  'todas': 266,
#  'ciudades': 267,
#  'Europa': 268,
#  'occidental': 269,
#  'tratando': 270,
#  'cascos': 271,
#  'urbanos': 272,
#  'habitables': 273,
#  'A': 274,
#  'juicio': 275,
#  'razones': 276,
#  'llevar': 277,
#  'adelante': 278,
#  'estas': 279,
#  'crematísticas': 280,
#  'mercenarias': 281,
#  'pero': 282,
#  'tienen': 283,
#  'nada': 284,
#  'ver': 285,
#  'futuro': 286,
#  'ni': 287,
#  'bienestar': 288,
#  'inmensa': 289,
#  'mayoría': 290,
#  'población': 291,
#  'Cantabria': 292,
#  'Fráncfort': 293,
#  'RFA': 294,
#  'EFECOM': 295,
#  'grupo': 296,
#  'alemán': 297,
#  'telefonía': 298,
#  'Deutsche': 299,
#  'Telekom': 300,
#  'adquirido': 301,
#  '50': 302,
#  'ciento': 303,
#  'restante': 304,
#  'operador': 305,
#  'suizo': 306,
#  'telecomunicaciones': 307,
#  'Multilink': 308,
#  'hasta': 309,
#  'ahora': 310,
#  'poseía': 311,
#  'France': 312,
#  'Telecom': 313,
#  'único': 314,
#  'propietario': 315,
#  'informó': 316,
#  'hoy,': 317,
#  'jueves': 318,
#  'compañía': 319,
#  'germana': 320,
#  'Como': 321,
#  'contrapartida': 322,
#  'venderá': 323,
#  'consorcio': 324,
#  'francés': 325,
#  'participación': 326,
#  'empresa': 327,
#  'mixta': 328,
#  'británica': 329,
#  'MetroHoldings': 330,
#  'fue': 331,
#  'creada': 332,
#  '1998': 333,
#  'ofrece': 334,
#  'servicios': 335,
#  'telefónicos': 336,
#  'transmisión': 337,
#  'Suiza': 338,
#  'extranjero': 339,
#  'además': 340,
#  'tener': 341,
#  'red': 342,
#  'urbana': 343,
#  'propia': 344,
#  'fibra': 345,
#  'óptica': 346,
#  'calificó': 347,
#  'esta': 348,
#  'compra': 349,
#  'cuyo': 350,
#  'precio': 351,
#  'especificó': 352,
#  'otro': 353,
#  'paso': 354,
#  'hacia': 355,
#  'internacionalización': 356,
#  'mediante': 357,
#  'adquisiciones': 358,
#  'mayoritarias': 359,
#  'destinadas': 360,
#  'control': 361,
#  'dirección': 362,
#  'esas': 363,
#  'empresas': 364,
#  '============================================================': 365,
#  'Mérida': 366,
#  'Delegación': 367,
#  'Agencia': 368,
#  'Extremadura': 369,
#  'transmitirá': 370,
#  'jueves,': 371,
#  'día': 372,
#  'otras': 373,
#  'siguientes': 374,
#  ':': 375,
#  'LASA': 376,
#  'ZABALA': 377,
#  'presidente': 378,
#  'Junta': 379,
#  'Juan': 380,
#  'Carlos': 381,
#  'Rodríguez': 382,
#  'Ibarra': 383,
#  'recibirá': 384,
#  'sede': 385,
#  'Presidencia': 386,
#  'Gobierno': 387,
#  'extremeño': 388,
#  'familiares': 389,
#  'varios': 390,
#  'condenados': 391,
#  'Lasa-Zabala': 392,
#  'ellos': 393,
#  'Lourdes': 394,
#  'Díez': 395,
#  'Urraca': 396,
#  'esposa': 397,
#  'ex': 398,
#  'gobernador': 399,
#  'civil': 400,
#  'Guipúzcoa': 401,
#  'Julen': 402,
#  'Elgorriaga': 403,
#  ';': 404,
#  'Antonio': 405,
#  'Galindo': 406,
#  'hermano': 407,
#  'general': 408,
#  'Enrique': 409,
#  'fotografía': 410,
#  'PLENO': 411,
#  'ASAMBLEA': 412,
#  'Pleno': 413,
#  'Asamblea': 414,
#  'debatirá': 415,
#  'proposición': 416,
#  'ley': 417,
#  'grupos': 418,
#  'PSOE-NI': 419,
#  'Mixto-Diputados': 420,
#  'insta': 421,
#  'central': 422,
#  'promulgar': 423,
#  'Orden': 424,
#  'Ministerial': 425,
#  'recoja': 426,
#  'regionalización': 427,
#  'superficie': 428,
#  'base': 429,
#  'cultivo': 430,
#  'maíz': 431,
#  'EMPRENDEDORES': 432,
#  'consejero': 433,
#  'Economía,': 434,
#  'Industria.': 435,
#  'Comercio': 436,
#  'Manuel': 437,
#  'Amigo': 438,
#  'presidentes': 439,
#  'Caja': 440,
#  'Badajoz': 441,
#  'Jesús': 442,
#  'Medina': 443,
#  'José': 444,
#  'Sánchez': 445,
#  'Rojas': 446,
#  'respectivamente': 447,
#  'suscribirán': 448,
#  'convenio': 449,
#  'colaboración': 450,
#  'financiar': 451,
#  'proyectos': 452,
#  'empresariales': 453,
#  'jóvenes': 454,
#  'emprendedores': 455,
#  'CARLOS': 456,
#  'V': 457,
#  'CONGRESO': 458,
#  'Jaraíz': 459,
#  'Vera': 460,
#  'Cáceres': 461,
#  'Instituto': 462,
#  'Histórico': 463,
#  'Hoffmeyer': 464,
#  'acogerá': 465,
#  'inauguración': 466,
#  'primera': 467,
#  'sesión': 468,
#  'Congreso': 469,
#  'Historia': 470,
#  'Moderna': 471,
#  'Carlos.': 472,
#  'fin': 473,
#  'época.': 474,
#  '1500-1558': 475,
#  'enmarca': 476,
#  'actos': 477,
#  'conmemorativos': 478,
#  'Centenario': 479,
#  'nacimiento': 480,
#  'emperador': 481,
#  'Agenda': 482,
#  'informativa': 483,
#  '10:00': 484,
#  'h.': 485,
#  'Comenzará': 486,
#  'Vivienda,': 487,
#  'Urbanismo.': 488,
#  'Transportes': 489,
#  'Javier': 490,
#  'Corominas': 491,
#  'entregará': 492,
#  '94': 493,
#  'viviendas': 494,
#  'régimen': 495,
#  'especial': 496,
#  'construidas': 497,
#  'Grupo': 498,
#  'Magenta': 499,
#  'Corchera': 500,
#  '10:30': 501,
#  'Plasencia': 502,
#  'alcalde': 503,
#  'Luis': 504,
#  'hablará': 505,
#  'diversas': 506,
#  'cuestiones': 507,
#  'interés': 508,
#  '11:00': 509,
#  'Se': 510,
#  'celebrará': 511,
#  '12:00': 512,
#  'Montijo': 513,
#  'Cultura': 514,
#  'Francisco': 515,
#  'Muñoz': 516,
#  'inaugurará': 517,
#  'IV': 518,
#  'Feria': 519,
#  'Libro': 520,
#  'local': 521,
#  'Azuaga': 522,
#  'Inauguración': 523,
#  'XIX': 524,
#  'Muestras': 525,
#  'Campiña': 526,
#  'Sur': 527,
#  'FECSUR': 528,
#  '12:30': 529,
#  'recalificación': 530,
#  'terrenos': 531,
#  'aledaños': 532,
#  'Colegio': 533,
#  'Salesianos': 534,
#  '20:30': 535,
#  'asistirá': 536,
#  'presentación': 537,
#  'libro': 538,
#  'Seres.': 539,
#  'Estrellas': 540,
#  'analiza': 541,
#  'orígenes': 542,
#  'Universo': 543,
#  'proyecto': 544,
#  'investigación': 545,
#  'Los': 546,
#  'Primeros': 547,
#  'Pobladores': 548,
#  'televisión': 549,
#  'pública': 550,
#  'sociedad': 551,
#  'financiación': 552,
#  'autonómica': 553,
#  'jornada': 554,
#  'extraescolar': 555,
#  'creación': 556,
#  'Consultivo': 557,
#  'primeros': 558,
#  'asuntos': 559,
#  'negociarán': 560,
#  'partir': 561,
#  'mañana': 562,
#  'alcanzar': 563,
#  'pacto': 564,
#  'regional': 565,
#  '13': 566,
#  'Continuarán': 567,
#  'actividades': 568,
#  'Agora.': 569,
#  'peninsular': 570,
#  'Caius': 571,
#  'Apicius': 572,
#  'Madrid': 573,
#  'Un': 574,
#  'vicio': 575,
#  'debe': 576,
#  'incurrir': 577,
#  'jamás': 578,
#  'quien': 579,
#  'tenga': 580,
#  'gastrónomo': 581,
#  'aspire': 582,
#  'ser': 583,
#  'reconocido': 584,
#  'tal': 585,
#  'patriotería': 586,
#  'entendida': 587,
#  'alarde': 588,
#  'excesivo': 589,
#  'e': 590,
#  'inoportuno': 591,
#  'patriotismo': 592,
#  'apátrida': 593,
#  'huir': 594,
#  'peste': 595,
#  'chovinismo': 596,
#  'Hace': 597,
#  'años': 598,
#  'uno': 599,
#  'libros': 600,
#  'viaje': 601,
#  'Nobel': 602,
#  'Literatura': 603,
#  'Camilo': 604,
#  'Cela': 605,
#  'afirmaba': 606,
#  'patriota': 607,
#  'está': 608,
#  'orgulloso': 609,
#  'nacido': 610,
#  'defiende': 611,
#  'actitud': 612,
#  'razón': 613,
#  'mientras': 614,
#  'patriotero': 615,
#  'entonces': 616,
#  'usaba': 617,
#  'palabra': 618,
#  "'": 619,
#  'nacionalista': 620,
#  'proclama': 621,
#  'contra': 622,
#  'viento.': 623,
#  'marea': 624,
#  'tierra': 625,
#  'natal': 626,
#  'superior': 627,
#  'demás': 628,
#  'cosa': 629,
#  'decía': 630,
#  'bien': 631,
#  'pudiera': 632,
#  'En': 633,
#  'esto': 634,
#  'comida': 635,
#  'abunda': 636,
#  'demasiado': 637,
#  'Uno': 638,
#  'ningún': 639,
#  'inconveniente': 640,
#  'aceptar': 641,
#  'cada': 642,
#  'cual': 643,
#  'defienda': 644,
#  'cocina': 645,
#  'productos': 646,
#  '...': 647,
#  'siempre': 648,
#  'esa': 649,
#  'implique': 650,
#  'desprecio': 651,
#  'cuanto': 652,
#  'ajeno': 653,
#  'costumbres': 654,
#  'gastronómicas': 655,
#  'solar': 656,
#  'patrio': 657,
#  'habrá': 658,
#  'pasar': 659,
#  'Machado': 660,
#  'recordar': 661,
#  'aquello': 662,
#  'desprecia': 663,
#  'ignora': 664,
#  'problema': 665,
#  'gastronómica': 666,
#  'nos': 667,
#  'engañemos': 668,
#  'cualquier': 669,
#  'otra': 670,
#  'ése': 671,
#  'justamente': 672,
#  'ignorancia': 673,
#  'Claro': 674,
#  'misma': 675,
#  'puede': 676,
#  'caer': 677,
#  'muchos': 678,
#  'defecto': 679,
#  'contrario': 680,
#  'digamos': 681,
#  'papanatismo': 682,
#  'hace': 683,
#  'estos': 684,
#  'ciudadanos': 685,
#  'mejor': 686,
#  'Pues': 687,
#  'tampoco': 688,
#  'algo': 689,
#  'así': 690,
#  'viajero': 691,
#  'turista': 692,
#  'estilo': 693,
#  'siglo': 694,
#  'curiosidad': 695,
#  'liberada': 696,
#  'posible': 697,
#  'prejuicios': 698,
#  'dispuesta': 699,
#  'cosas': 700,
#  'buenas': 701,
#  'sin': 702,
#  'ello': 703,
#  'renegar': 704,
#  'propias': 705,
#  'Pero': 706,
#  'universalidad': 707,
#  'universalizaron': 708,
#  'gastronomía': 709,
#  'fueron': 710,
#  'romanos': 711,
#  'implica': 712,
#  'renuncia': 713,
#  'propio': 714,
#  'Mucho': 715,
#  'menos': 716,
#  'mezcolanzas': 717,
#  'absurdas': 718,
#  'llamamos': 719,
#  'fusión': 720,
#  'muy': 721,
#  'defendible': 722,
#  'siempre.': 723,
#  'derive': 724,
#  'tantos': 725,
#  'casos': 726,
#  'confusión': 727,
#  'Insistiremos': 728,
#  'verdad': 729,
#  'grande': 730,
#  'fiel': 731,
#  'cómo': 732,
#  'estar': 733,
#  'abierta': 734,
#  'incorporaciones': 735,
#  'foráneas': 736,
#  'Qué': 737,
#  'sería': 738,
#  'europea': 739,
#  'ejemplo': 740,
#  'patatas': 741,
#  'mediterránea': 742,
#  'tomates': 743,
#  'ambos': 744,
#  'llegaron': 745,
#  'Viejo': 746,
#  'Mundo': 747,
#  'cinco': 748,
#  'siglos': 749,
#  'Imagínense': 750,
#  'ustedes': 751,
#  'aquellos': 752,
#  'españoles': 753,
#  'quienes': 754,
#  'llevaron': 755,
#  'esos': 756,
#  'dones': 757,
#  'americanos': 758,
#  'hubiera': 759,
#  'impuesto': 760,
#  'hubieran': 761,
#  'quedado': 762,
#  'curiosidades': 763,
#  'botánicas': 764,
#  'No': 765,
#  'universal': 766,
#  'recuerden': 767,
#  'horror': 768,
#  'conocido': 769,
#  'internacional': 770,
#  'tan': 771,
#  'frecuente': 772,
#  'restaurantes': 773,
#  'hotel': 774,
#  'encerrada': 775,
#  'sí': 776,
#  'cabe': 777,
#  'preguntarse': 778,
#  'alimento': 779,
#  'nueva': 780,
#  'especia': 781,
#  '¿': 782,
#  'dónde': 783,
#  'viene': 784,
#  '?': 785,
#  'investigar': 786,
#  'antes': 787,
#  'verdaderamente': 788,
#  'importante': 789,
#  'rico': 790,
#  'si': 791,
#  'viniere': 792,
#  'supuesto': 793,
#  'estudiar': 794,
#  'adaptamos': 795,
#  'producto': 796,
#  'nuestros': 797,
#  'usos': 798,
#  'culinarios': 799,
#  'arraigados': 800,
#  'Así': 801,
#  'nuestra': 802,
#  'evoluciona': 803,
#  'enriquece': 804,
#  'De': 805,
#  'manera': 806,
#  'encerrándose': 807,
#  'acaba': 808,
#  'debilitarse': 809,
#  'extinguirse': 810,
#  'endogamia': 811,
#  'buena': 812,
#  'casi': 813,
#  'Tengan': 814,
#  'pues': 815,
#  'mente': 816,
#  'sentidos': 817,
#  'todavía': 818,
#  'Que': 819,
#  'parafraseando': 820,
#  'Shakespeare': 821,
#  'Hamlet': 822,
#  'ricas': 823,
#  'Tierra': 824,
#  'alcanza': 825,
#  'tu': 826,
#  'sabiduría': 827,
#  'experiencia': 828,
#  'personal': 829,
#  'conviertan': 830,
#  'eunucos': 831,
#  'gusto': 832,
#  'mera': 833,
#  'perderán': 834,
#  'tantas': 835,
#  'Alcorcón': 836,
#  'Museo': 837,
#  'Arte': 838,
#  'vidrio': 839,
#  'acoge': 840,
#  'desde': 841,
#  'próximo': 842,
#  '28': 843,
#  'junio': 844,
#  'exposición': 845,
#  'esculturas': 846,
#  'artista': 847,
#  'rumano': 848,
#  'Edward': 849,
#  'Leibovtiz': 850,
#  'compuesta': 851,
#  '35': 852,
#  'piezas': 853,
#  'diferentes': 854,
#  'formatos': 855,
#  'tamaño': 856,
#  'oscila': 857,
#  '40': 858,
#  'centímetros': 859,
#  '2': 860,
#  'metros': 861,
#  'algunas': 862,
#  'figuras': 863,
#  'Las': 864,
#  'muestra': 865,
#  'organizada': 866,
#  'Concejalía': 867,
#  'carácter': 868,
#  'figurativo': 869,
#  'ellas': 870,
#  'aprecian': 871,
#  'caras': 872,
#  'cuerpos': 873,
#  'distintas': 874,
#  'fantasías': 875,
#  'mostrando': 876,
#  'incluso': 877,
#  'aspectos': 878,
#  'eróticos': 879,
#  'Leibovitz': 880,
#  'reside': 881,
#  'Bélgica': 882,
#  'actualidad': 883,
#  'expuesto': 884,
#  '30': 885,
#  'trabajo': 886,
#  'escultor': 887,
#  'contemporáneo': 888,
#  'numerosos': 889,
#  'museos': 890,
#  'europeos': 891,
#  'asiáticos': 892,
#  'países': 893,
#  'Japón': 894,
#  'Alemania': 895,
#  'Francia': 896,
#  'Israel': 897,
#  'asistentes': 898,
#  'tarde': 899,
#  'podrán': 900,
#  'disfrutar': 901,
#  'señala': 902,
#  'me': 903,
#  'gusta': 904,
#  'trabajar': 905,
#  'composición': 906,
#  'pieza': 907,
#  'trato': 908,
#  'transmitir': 909,
#  'fantasía': 910,
#  'vida': 911,
#  'aspecto': 912,
#  'absurdo': 913,
#  'prevista': 914,
#  '20': 915,
#  'horas': 916,
#  'concejal': 917,
#  'Torres': 918,
#  'cuya': 919,
#  'cursado': 920,
#  'invitación': 921,
#  'embajadores': 922,
#  'Rumanía': 923,
#  'consulados': 924,
#  'según': 925,
#  'fuentes': 926,
#  'han': 927,
#  'confirmado': 928,
#  'presencia': 929,
#  'distintos': 930,
#  'representantes': 931,
#  'ampliación': 932,
#  'máxima': 933,
#  'Terra': 934,
#  'canje': 935,
#  'acciones': 936,
#  'Lycos': 937,
#  'incluidas': 938,
#  'opciones': 939,
#  'trabajadores': 940,
#  'estadounidense': 941,
#  'excederá': 942,
#  '340.922.712': 943,
#  'cierre': 944,
#  'ayer': 945,
#  'bolsa': 946,
#  '50,9': 947,
#  'pesetas': 948,
#  'acción': 949,
#  '2,887': 950,
#  'billones': 951,
#  'consta': 952,
#  'nota': 953,
#  'aclaratoria': 954,
#  'Telefónica': 955,
#  'Comisión': 956,
#  'Nacional': 957,
#  'Mercado': 958,
#  'Valores': 959,
#  'ampliaciones': 960,
#  'serán': 961,
#  'sometidas': 962,
#  'aprobación': 963,
#  'Accionistas': 964,
#  'cabo': 965,
#  'operación': 966,
#  'filial': 967,
#  'Network': 968,
#  'portal': 969,
#  'Internet': 970,
#  'aclaración': 971,
#  'indica': 972,
#  'trata': 973,
#  'máximas': 974,
#  'cubrir': 975,
#  'acuerdos': 976,
#  'realizado': 977,
#  'dice': 978,
#  'americana': 979,
#  '112.192.815': 980,
#  'previstas': 981,
#  'adquisición': 982,
#  'activos': 983,
#  'importe': 984,
#  '9,7': 985,
#  'millones': 986,
#  'títulos': 987,
#  'Además': 988,
#  'empleados': 989,
#  'planes': 990,
#  '23.640.000': 991,
#  'otros': 992,
#  '7.440.000': 993,
#  'máximo': 994,
#  'podrían': 995,
#  'emitidas': 996,
#  'total': 997,
#  '158.568.703': 998,
#  'cambiarían': 999,
#  ...}

# %%
sent2tokens(train_sents[0])
# Out:
# ['Melbourne', '(', 'Australia', ')', ',', '25', 'may', '(', 'EFE', ')', '.']

# %% [markdown]
# This is what word2features extracts:

# %%
sent2features(train_sents[0])[0]
# Out:
# {'bias': 1.0,
#  'word.lower()': 'melbourne',
#  'word[-3:]': 'rne',
#  'word[-2:]': 'ne',
#  'word.isupper()': False,
#  'word.istitle()': True,
#  'word.isdigit()': False,
#  'postag': 'NP',
#  'postag[:2]': 'NP',
#  'BOS': True,
#  '+1:word.lower()': '(',
#  '+1:word.istitle()': False,
#  '+1:word.isupper()': False,
#  '+1:postag': 'Fpa',
#  '+1:postag[:2]': 'Fp'}

# %% [markdown]
# Extract features from the data:

# %%
X_train = [sent2features(s) for s in train_sents]
y_train = [sent2labels(s) for s in train_sents]

X_test = [sent2features(s) for s in test_sents]
y_test = [sent2labels(s) for s in test_sents]

# %%
y_train[0]
# Out:
# ['B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O']

# %% [markdown]
# ## Training
#
# To see all possible CRF parameters check its docstring. Here we are useing L-BFGS training algorithm (it is default) with Elastic Net (L1 + L2) regularization.

# %%
# ?sklearn_crfsuite.CRF

# %%
# %%time
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    c1=0.1, 
    c2=0.1, 
    max_iterations=100, 
    all_possible_transitions=True
)

crf.fit(X_train, y_train)
# Out:
# CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=True,
#     averaging=None, c=None, c1=0.1, c2=0.1, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %%
crf.attributes_
# Out:
# ['bias',
#  'word.lower():melbourne',
#  'word[-3:]:rne',
#  'word[-2:]:ne',
#  'word.isupper()',
#  'word.istitle()',
#  'word.isdigit()',
#  'postag:NP',
#  'postag[:2]:NP',
#  'BOS',
#  '+1:word.lower():(',
#  '+1:word.istitle()',
#  '+1:word.isupper()',
#  '+1:postag:Fpa',
#  '+1:postag[:2]:Fp',
#  'word.lower():(',
#  'word[-3:]:(',
#  'word[-2:]:(',
#  'postag:Fpa',
#  'postag[:2]:Fp',
#  '-1:word.istitle()',
#  '-1:word.isupper()',
#  '-1:postag:NP',
#  '-1:postag[:2]:NP',
#  '+1:postag:NP',
#  '+1:postag[:2]:NP',
#  'word.lower():australia',
#  'word[-3:]:lia',
#  'word[-2:]:ia',
#  '-1:word.lower():(',
#  '-1:postag:Fpa',
#  '-1:postag[:2]:Fp',
#  '+1:word.lower():)',
#  '+1:postag:Fpt',
#  'word.lower():)',
#  'word[-3:]:)',
#  'word[-2:]:)',
#  'postag:Fpt',
#  '+1:word.lower():,',
#  '+1:postag:Fc',
#  '+1:postag[:2]:Fc',
#  'word.lower():,',
#  'word[-3:]:,',
#  'word[-2:]:,',
#  'postag:Fc',
#  'postag[:2]:Fc',
#  '-1:word.lower():)',
#  '-1:postag:Fpt',
#  '+1:word.lower():25',
#  '+1:postag:Z',
#  '+1:postag[:2]:Z',
#  'word.lower():25',
#  'word[-3:]:25',
#  'word[-2:]:25',
#  'postag:Z',
#  'postag[:2]:Z',
#  '-1:word.lower():,',
#  '-1:postag:Fc',
#  '-1:postag[:2]:Fc',
#  '+1:postag:NC',
#  '+1:postag[:2]:NC',
#  'word.lower():may',
#  'word[-2:]:ay',
#  'postag:NC',
#  'postag[:2]:NC',
#  '-1:word.lower():25',
#  '-1:postag:Z',
#  '-1:postag[:2]:Z',
#  '-1:postag:NC',
#  '-1:postag[:2]:NC',
#  '+1:word.lower():efe',
#  'word.lower():efe',
#  'word[-3:]:EFE',
#  'word[-2:]:FE',
#  '-1:word.lower():efe',
#  '+1:word.lower():.',
#  '+1:postag:Fp',
#  'word.lower():.',
#  'word[-3:]:.',
#  'word[-2:]:.',
#  'postag:Fp',
#  'EOS',
#  'word.lower():-',
#  'word[-3:]:-',
#  'word[-2:]:-',
#  'postag:Fg',
#  'postag[:2]:Fg',
#  'word.lower():el',
#  'word[-3:]:El',
#  'word[-2:]:El',
#  'postag:DA',
#  'postag[:2]:DA',
#  'word.lower():abogado',
#  'word[-3:]:ado',
#  'word[-2:]:do',
#  '-1:word.lower():el',
#  '-1:postag:DA',
#  '-1:postag[:2]:DA',
#  '+1:word.lower():general',
#  '+1:postag:AQ',
#  '+1:postag[:2]:AQ',
#  'word.lower():general',
#  'word[-3:]:ral',
#  'word[-2:]:al',
#  'postag:AQ',
#  'postag[:2]:AQ',
#  '-1:word.lower():abogado',
#  '+1:word.lower():del',
#  '+1:postag:SP',
#  '+1:postag[:2]:SP',
#  'word.lower():del',
#  'word[-3:]:del',
#  'word[-2:]:el',
#  'postag:SP',
#  'postag[:2]:SP',
#  '-1:word.lower():general',
#  '-1:postag:AQ',
#  '-1:postag[:2]:AQ',
#  '+1:word.lower():estado',
#  'word.lower():estado',
#  '-1:word.lower():del',
#  '-1:postag:SP',
#  '-1:postag[:2]:SP',
#  '-1:word.lower():estado',
#  '+1:postag:VMI',
#  '+1:postag[:2]:VM',
#  'word[-2:]:yl',
#  'postag:VMI',
#  'postag[:2]:VM',
#  '+1:word.lower():williams',
#  'word.lower():williams',
#  'word[-3:]:ams',
#  'word[-2:]:ms',
#  '-1:postag:VMI',
#  '-1:postag[:2]:VM',
#  '-1:word.lower():williams',
#  '+1:word.lower():subrayó',
#  'word[-3:]:ayó',
#  'word[-2:]:yó',
#  '+1:word.lower():hoy',
#  '+1:postag:RG',
#  '+1:postag[:2]:RG',
#  'word.lower():hoy',
#  'word[-2:]:oy',
#  'postag:RG',
#  'postag[:2]:RG',
#  '-1:word.lower():subrayó',
#  '+1:word.lower():la',
#  '+1:postag:DA',
#  '+1:postag[:2]:DA',
#  'word.lower():la',
#  'word[-3:]:la',
#  'word[-2:]:la',
#  '-1:word.lower():hoy',
#  '-1:postag:RG',
#  '-1:postag[:2]:RG',
#  'word[-3:]:dad',
#  'word[-2:]:ad',
#  '-1:word.lower():la',
#  '+1:word.lower():de',
#  'word.lower():de',
#  'word[-3:]:de',
#  'word[-2:]:de',
#  '+1:postag:VMN',
#  'word[-3:]:mar',
#  'word[-2:]:ar',
#  'postag:VMN',
#  '-1:word.lower():de',
#  'word[-3:]:das',
#  'word[-2:]:as',
#  '-1:word.lower():tomar',
#  '-1:postag:VMN',
#  '+1:word.lower():para',
#  'word.lower():para',
#  'word[-3:]:ara',
#  'word[-2:]:ra',
#  'word[-3:]:ger',
#  'word[-2:]:er',
#  '-1:word.lower():para',
#  '+1:word.lower():al',
#  'word.lower():al',
#  'word[-3:]:al',
#  '+1:word.lower():sistema',
#  'word.lower():sistema',
#  'word[-3:]:ema',
#  'word[-2:]:ma',
#  '-1:word.lower():al',
#  '+1:word.lower():judicial',
#  'word.lower():judicial',
#  'word[-3:]:ial',
#  '-1:word.lower():sistema',
#  'word.lower():australiano',
#  'word[-3:]:ano',
#  'word[-2:]:no',
#  '-1:word.lower():judicial',
#  '+1:word.lower():frente',
#  'word.lower():frente',
#  'word[-3:]:nte',
#  'word[-2:]:te',
#  '+1:word.lower():a',
#  'word.lower():a',
#  'word[-3:]:a',
#  'word[-2:]:a',
#  '-1:word.lower():frente',
#  '+1:word.lower():una',
#  '+1:postag:DI',
#  '+1:postag[:2]:DI',
#  'word.lower():una',
#  'word[-3:]:una',
#  'word[-2:]:na',
#  'postag:DI',
#  'postag[:2]:DI',
#  '-1:word.lower():a',
#  'word[-3:]:ina',
#  '-1:word.lower():una',
#  '-1:postag:DI',
#  '-1:postag[:2]:DI',
#  '-1:word.lower():página',
#  '+1:word.lower():internet',
#  'word.lower():internet',
#  'word[-3:]:net',
#  'word[-2:]:et',
#  '+1:word.lower():que',
#  '+1:postag:PR',
#  '+1:postag[:2]:PR',
#  'word.lower():que',
#  'word[-3:]:que',
#  'word[-2:]:ue',
#  'postag:PR',
#  'postag[:2]:PR',
#  '-1:word.lower():internet',
#  'word[-3:]:ita',
#  'word[-2:]:ta',
#  '-1:word.lower():que',
#  '-1:postag:PR',
#  '-1:postag[:2]:PR',
#  '+1:word.lower():el',
#  'word[-3:]:el',
#  'word[-3:]:nto',
#  'word[-2:]:to',
#  '+1:word.lower():los',
#  'word.lower():los',
#  'word[-3:]:los',
#  'word[-2:]:os',
#  'word[-3:]:ios',
#  '-1:word.lower():los',
#  'word[-3:]:cos',
#  '+1:word.lower():ley',
#  'word.lower():ley',
#  'word[-3:]:Ley',
#  'word[-2:]:ey',
#  '-1:word.lower():ley',
#  'word[-3:]:La',
#  'word[-2:]:La',
#  'word[-3:]:ión',
#  'word[-2:]:ón',
#  '+1:word.lower():tiene',
#  'word.lower():tiene',
#  'word[-3:]:ene',
#  'word[-3:]:gar',
#  '-1:word.lower():tiene',
#  '+1:word.lower():después',
#  'word[-3:]:ués',
#  'word[-2:]:és',
#  '+1:postag:CS',
#  '+1:postag[:2]:CS',
#  'postag:CS',
#  'postag[:2]:CS',
#  '+1:word.lower():un',
#  'word.lower():un',
#  'word[-3:]:un',
#  'word[-2:]:un',
#  '-1:postag:CS',
#  '-1:postag[:2]:CS',
#  'word[-3:]:uez',
#  'word[-2:]:ez',
#  '-1:word.lower():un',
#  '+1:word.lower():tribunal',
#  'word.lower():tribunal',
#  'word[-3:]:nal',
#  '+1:word.lower():supremo',
#  'word.lower():supremo',
#  'word[-3:]:emo',
#  'word[-2:]:mo',
#  '-1:word.lower():tribunal',
#  '-1:word.lower():supremo',
#  '+1:word.lower():victoria',
#  'word.lower():victoria',
#  'word[-3:]:ria',
#  '-1:word.lower():victoria',
#  '+1:word.lower():se',
#  '+1:postag:P0',
#  '+1:postag[:2]:P0',
#  'word.lower():se',
#  'word[-3:]:se',
#  'word[-2:]:se',
#  'postag:P0',
#  'postag[:2]:P0',
#  '+1:postag:VMS',
#  'word[-3:]:era',
#  'postag:VMS',
#  '-1:word.lower():se',
#  '-1:postag:P0',
#  '-1:postag[:2]:P0',
#  '-1:postag:VMS',
#  'word[-3:]:ver',
#  '+1:word.lower():popular',
#  'word.lower():popular',
#  'word[-3:]:lar',
#  '+1:word.lower():y',
#  '+1:postag:CC',
#  '+1:postag[:2]:CC',
#  'word.lower():y',
#  'word[-3:]:y',
#  'word[-2:]:y',
#  'postag:CC',
#  'postag[:2]:CC',
#  '-1:word.lower():popular',
#  'word[-3:]:der',
#  '-1:word.lower():y',
#  '-1:postag:CC',
#  '-1:postag[:2]:CC',
#  'word.lower():proceso',
#  'word[-3:]:eso',
#  'word[-2:]:so',
#  '+1:word.lower():ante',
#  '-1:word.lower():proceso',
#  '-1:word.lower():ante',
#  '+1:word.lower():defensa',
#  'word.lower():defensa',
#  'word[-3:]:nsa',
#  'word[-2:]:sa',
#  '-1:word.lower():defensa',
#  '+1:word.lower():las',
#  'word.lower():las',
#  'word[-3:]:las',
#  '+1:word.lower():personas',
#  'word.lower():personas',
#  'word[-3:]:nas',
#  '-1:word.lower():las',
#  '+1:word.lower():lo',
#  '+1:postag:PP',
#  '+1:postag[:2]:PP',
#  'word.lower():lo',
#  'word[-3:]:lo',
#  'word[-2:]:lo',
#  'postag:PP',
#  'postag[:2]:PP',
#  'word[-2:]:an',
#  '-1:word.lower():lo',
#  '-1:postag:PP',
#  '-1:postag[:2]:PP',
#  '+1:word.lower():haber',
#  '+1:postag:VAN',
#  '+1:postag[:2]:VA',
#  'word[-3:]:ber',
#  'postag[:2]:VA',
#  '+1:postag:VMP',
#  'word[-3:]:ido',
#  'postag:VMP',
#  '-1:postag[:2]:VA',
#  '+1:word.lower():información',
#  'word.lower():información',
#  '-1:postag:VMP',
#  '+1:word.lower():sobre',
#  'word.lower():sobre',
#  'word[-3:]:bre',
#  'word[-2:]:re',
#  '-1:word.lower():información',
#  '-1:word.lower():sobre',
#  'word.lower():través',
#  'word[-3:]:vés',
#  'word.lower():crimenet',
#  'word[-3:]:Net',
#  'word.lower():esta',
#  'word[-3:]:sta',
#  'postag:DD',
#  'postag[:2]:DD',
#  '-1:word.lower():esta',
#  '-1:postag:DD',
#  '-1:postag[:2]:DD',
#  '+1:word.lower():web',
#  'word.lower():web',
#  'word[-3:]:web',
#  'word[-2:]:eb',
#  'word[-3:]:eva',
#  'word[-2:]:va',
#  '-1:word.lower():web',
#  'word[-3:]:mes',
#  'word[-2:]:es',
#  'word[-3:]:cia',
#  '+1:word.lower():tiempo',
#  'word.lower():tiempo',
#  'word[-3:]:mpo',
#  'word[-2:]:po',
#  '+1:word.lower():en',
#  'word.lower():en',
#  'word[-3:]:en',
#  'word[-2:]:en',
#  '-1:word.lower():tiempo',
#  '-1:word.lower():en',
#  '+1:word.lower():ha',
#  '+1:postag:VAI',
#  'word.lower():ha',
#  'word[-3:]:ha',
#  'word[-2:]:ha',
#  'postag:VAI',
#  '+1:word.lower():sido',
#  '+1:postag:VSP',
#  '+1:postag[:2]:VS',
#  'postag[:2]:VS',
#  '-1:word.lower():ha',
#  '-1:postag:VAI',
#  'word[-3:]:ada',
#  'word[-2:]:da',
#  '-1:postag[:2]:VS',
#  '+1:word.lower():más',
#  'word.lower():más',
#  'word[-3:]:más',
#  'word[-2:]:ás',
#  '-1:word.lower():más',
#  'word[-3:]:lón',
#  'word[-3:]:nes',
#  '-1:word.lower():ocasiones',
#  '+1:postag:PN',
#  '+1:postag[:2]:PN',
#  'word[-3:]:les',
#  'postag:PN',
#  'postag[:2]:PN',
#  '-1:postag:PN',
#  '-1:postag[:2]:PN',
#  '+1:postag:VMM',
#  'postag:VMM',
#  '+1:word.lower():ya',
#  'word.lower():ya',
#  'word[-2:]:ya',
#  '-1:postag:VMM',
#  'word[-3:]:dos',
#  '-1:word.lower():ya',
#  '+1:word.lower():o',
#  'word.lower():o',
#  'word[-3:]:o',
#  'word[-2:]:o',
#  'word[-2:]:ún',
#  '-1:word.lower():o',
#  '+1:word.lower():datos',
#  'word.lower():datos',
#  'word[-3:]:tos',
#  '-1:word.lower():datos',
#  'word[-3:]:len',
#  'word[-3:]:vos',
#  'word.lower():por',
#  'word[-3:]:Por',
#  'word[-2:]:or',
#  '+1:word.lower():su',
#  '+1:postag:DP',
#  '+1:postag[:2]:DP',
#  'word.lower():su',
#  'word[-3:]:su',
#  'word[-2:]:su',
#  'postag:DP',
#  'postag[:2]:DP',
#  '-1:word.lower():por',
#  '+1:word.lower():parte',
#  'word[-3:]:rte',
#  '-1:word.lower():su',
#  '-1:postag:DP',
#  '-1:postag[:2]:DP',
#  '-1:word.lower():parte',
#  'word[-3:]:lls',
#  'word[-2:]:ls',
#  '+1:word.lower():indicó',
#  'word.lower():indicó',
#  'word[-3:]:icó',
#  'word[-2:]:có',
#  '-1:word.lower():indicó',
#  '+1:word.lower():no',
#  '+1:postag:RN',
#  '+1:postag[:2]:RN',
#  'word.lower():no',
#  'word[-3:]:no',
#  'postag:RN',
#  'postag[:2]:RN',
#  '+1:word.lower():hay',
#  '-1:word.lower():no',
#  '-1:postag:RN',
#  '-1:postag[:2]:RN',
#  '+1:postag:PI',
#  '+1:postag[:2]:PI',
#  'word.lower():nadie',
#  'word[-3:]:die',
#  'word[-2:]:ie',
#  'postag:PI',
#  'postag[:2]:PI',
#  '-1:postag:PI',
#  '-1:postag[:2]:PI',
#  'word[-3:]:ole',
#  'word[-2:]:le',
#  '+1:word.lower():son',
#  '+1:postag:VSI',
#  'word.lower():son',
#  'word[-3:]:son',
#  'word[-2:]:on',
#  'postag:VSI',
#  'word[-3:]:ces',
#  '-1:word.lower():son',
#  '-1:postag:VSI',
#  '+1:word.lower():señaló',
#  'word.lower():señaló',
#  'word[-3:]:aló',
#  'word[-2:]:ló',
#  '-1:word.lower():señaló',
#  'word[-3:]:ico',
#  'word[-2:]:co',
#  'word.lower():commonwealth',
#  'word[-3:]:lth',
#  'word[-2:]:th',
#  'word[-3:]:asa',
#  '+1:word.lower():justicia',
#  'word.lower():justicia',
#  'word[-3:]:ana',
#  '-1:word.lower():justicia',
#  '+1:word.lower():es',
#  'word.lower():es',
#  'word[-3:]:es',
#  'word[-3:]:tal',
#  '-1:word.lower():es',
#  'word[-3:]:ona',
#  '+1:word.lower():sea',
#  '+1:postag:VSS',
#  'word[-3:]:sea',
#  'word[-2:]:ea',
#  '+1:postag:VMG',
#  'word[-3:]:ndo',
#  'postag:VMG',
#  '-1:postag:VMG',
#  '+1:word.lower():cuenta',
#  'word.lower():cuenta',
#  'word[-3:]:nta',
#  '-1:word.lower():cuenta',
#  'word.lower():pruebas',
#  'word[-3:]:bas',
#  '-1:word.lower():citada',
#  '+1:word.lower():considera',
#  'word.lower():considera',
#  '+1:word.lower():también',
#  'word.lower():también',
#  'word[-3:]:ién',
#  'word[-2:]:én',
#  '-1:word.lower():considera',
#  '-1:word.lower():también',
#  'word[-3:]:usa',
#  'word[-3:]:ura',
#  '+1:word.lower():caso',
#  'word.lower():caso',
#  'word[-3:]:aso',
#  '-1:word.lower():caso',
#  'word[-3:]:ato',
#  '+1:word.lower():juzgado',
#  'word.lower():juzgado',
#  '-1:word.lower():juzgado',
#  '+1:word.lower():ciudad',
#  'word.lower():ciudad',
#  '-1:word.lower():ciudad',
#  '+1:word.lower():melbourne',
#  '+1:word.lower():capital',
#  'word.lower():capital',
#  '-1:word.lower():capital',
#  'word.lower():santander',
#  '-1:word.lower():santander',
#  'word.lower():izquierda',
#  'word[-3:]:rda',
#  '+1:word.lower():unida',
#  'word.lower():unida',
#  'word[-3:]:ida',
#  '-1:word.lower():izquierda',
#  '-1:word.lower():unida',
#  '+1:word.lower():santander',
#  '+1:word.lower():presentó',
#  'word[-3:]:ntó',
#  'word[-2:]:tó',
#  '+1:word.lower():nuevo',
#  'word.lower():nuevo',
#  'word[-3:]:evo',
#  'word[-2:]:vo',
#  'word[-3:]:tín',
#  'word[-2:]:ín',
#  '-1:word.lower():nuevo',
#  '+1:word.lower():"',
#  '+1:postag:Fe',
#  '+1:postag[:2]:Fe',
#  'word.lower():"',
#  'word[-3:]:"',
#  'word[-2:]:"',
#  'postag:Fe',
#  'postag[:2]:Fe',
#  '-1:word.lower():"',
#  '-1:postag:Fe',
#  '-1:postag[:2]:Fe',
#  'word[-3:]:rán',
#  'word[-2:]:án',
#  'word[-3:]:000',
#  'word[-2:]:00',
#  'word[-3:]:res',
#  '+1:word.lower():municipio',
#  'word.lower():municipio',
#  'word[-3:]:pio',
#  'word[-2:]:io',
#  '+1:word.lower():donde',
#  'word[-3:]:nde',
#  '-1:word.lower():donde',
#  '+1:word.lower():con',
#  'word.lower():con',
#  'word[-3:]:con',
#  '+1:word.lower():mayor',
#  'word.lower():mayor',
#  'word[-3:]:yor',
#  '-1:word.lower():con',
#  'word[-3:]:ldo',
#  '-1:word.lower():mayor',
#  'word.lower():portavoz',
#  'word[-3:]:voz',
#  'word[-2:]:oz',
#  '-1:word.lower():portavoz',
#  '+1:word.lower():consejo',
#  'word.lower():consejo',
#  'word[-3:]:ejo',
#  'word[-2:]:jo',
#  '+1:word.lower():político',
#  'word.lower():político',
#  '-1:word.lower():consejo',
#  '+1:word.lower():municipal',
#  'word.lower():municipal',
#  'word[-3:]:pal',
#  '-1:word.lower():político',
#  '-1:word.lower():municipal',
#  '+1:word.lower():iu',
#  'word.lower():iu',
#  'word[-3:]:IU',
#  'word[-2:]:IU',
#  '-1:word.lower():iu',
#  'word[-3:]:sto',
#  '+1:word.lower():gómez',
#  'word.lower():gómez',
#  'word[-3:]:mez',
#  '-1:word.lower():gómez',
#  '+1:word.lower():hera',
#  'word.lower():hera',
#  '+1:word.lower():explicó',
#  'word.lower():explicó',
#  '-1:word.lower():explicó',
#  '+1:word.lower():conferencia',
#  'word.lower():conferencia',
#  '-1:word.lower():conferencia',
#  '+1:word.lower():prensa',
#  'word.lower():prensa',
#  '+1:word.lower():este',
#  '+1:postag:DD',
#  '+1:postag[:2]:DD',
#  'word.lower():este',
#  'word[-3:]:ste',
#  '-1:word.lower():este',
#  'word[-3:]:gue',
#  'word.lower():abrir',
#  'word[-3:]:rir',
#  'word[-2:]:ir',
#  '+1:word.lower():debate',
#  'word.lower():debate',
#  'word[-3:]:ate',
#  '-1:word.lower():debate',
#  '+1:word.lower():como',
#  'word.lower():como',
#  'word[-3:]:omo',
#  '-1:word.lower():como',
#  'word[-3:]:lla',
#  '+1:word.lower():política',
#  'word.lower():política',
#  'word[-3:]:ica',
#  'word[-2:]:ca',
#  '-1:word.lower():política',
#  '+1:word.lower():comentó',
#  '+1:word.lower():responden',
#  'word[-3:]:den',
#  'word.lower():programa',
#  'word[-3:]:ama',
#  '-1:word.lower():programa',
#  'word[-2:]:zó',
#  'word.lower():elecciones',
#  '+1:word.lower():municipales',
#  'word.lower():municipales',
#  '-1:word.lower():municipales',
#  '+1:word.lower():1999',
#  'word.lower():1999',
#  'word[-3:]:999',
#  'word[-2:]:99',
#  '+1:word.lower():perdió',
#  'word[-3:]:dió',
#  'word[-2:]:ió',
#  '-1:word.lower():perdió',
#  '+1:word.lower():ayuntamiento',
#  'word.lower():ayuntamiento',
#  '-1:word.lower():ayuntamiento',
#  '+1:word.lower():confió',
#  '+1:word.lower():vez',
#  'word.lower():vez',
#  'word[-3:]:vez',
#  'word.lower():coalición',
#  'word[-3:]:lva',
#  '-1:word.lower():coalición',
#  '+1:word.lower():crisis',
#  'word.lower():crisis',
#  'word[-3:]:sis',
#  'word[-2:]:is',
#  '+1:word.lower():económica',
#  '-1:word.lower():crisis',
#  '-1:word.lower():económica',
#  '+1:word.lower():momento',
#  'word.lower():momento',
#  '-1:word.lower():momento',
#  '+1:word.lower():será',
#  'word[-3:]:erá',
#  'word[-2:]:rá',
#  'word.lower():forma',
#  'word[-3:]:rma',
#  '+1:word.lower():entre',
#  'word.lower():entre',
#  'word[-3:]:tre',
#  '-1:word.lower():entre',
#  '-1:word.lower():norte',
#  '+1:word.lower():calle',
#  'word.lower():calle',
#  'word[-3:]:lle',
#  '+1:word.lower():alta',
#  'word.lower():alta',
#  'word[-3:]:lta',
#  '-1:word.lower():calle',
#  '-1:word.lower():alta',
#  'word.lower():cazoña',
#  'word[-3:]:oña',
#  'word[-2:]:ña',
#  '+1:word.lower():zona',
#  'word.lower():zona',
#  '-1:word.lower():zona',
#  '+1:word.lower():calles',
#  'word.lower():calles',
#  '+1:word.lower():castilla',
#  'word.lower():castilla',
#  '-1:word.lower():calles',
#  '-1:word.lower():castilla',
#  '+1:word.lower():hermida',
#  'word.lower():hermida',
#  '+1:word.lower():por',
#  'word[-3:]:por',
#  '+1:word.lower():dos',
#  '+1:postag:DN',
#  '+1:postag[:2]:DN',
#  'word.lower():dos',
#  'postag:DN',
#  'postag[:2]:DN',
#  '-1:word.lower():dos',
#  '-1:postag:DN',
#  '-1:postag[:2]:DN',
#  'word[-3:]:tad',
#  '+1:word.lower():sale',
#  'word[-3:]:ale',
#  '+1:word.lower():primer',
#  '+1:postag:AO',
#  '+1:postag[:2]:AO',
#  'word.lower():primer',
#  'word[-3:]:mer',
#  'postag:AO',
#  'postag[:2]:AO',
#  '+1:word.lower():número',
#  'word.lower():número',
#  'word[-3:]:ero',
#  'word[-2:]:ro',
#  '-1:word.lower():primer',
#  '-1:postag:AO',
#  '-1:postag[:2]:AO',
#  '-1:word.lower():número',
#  '+1:word.lower():obras',
#  'word.lower():obras',
#  'word[-3:]:ras',
#  '-1:word.lower():obras',
#  '+1:word.lower():construcción',
#  'word.lower():construcción',
#  'word[-3:]:eos',
#  'word[-3:]:ias',
#  '+1:word.lower():están',
#  'word[-3:]:tán',
#  '+1:word.lower():vecinos',
#  'word.lower():vecinos',
#  'word[-3:]:nos',
#  '-1:word.lower():vecinos',
#  'word[-3:]:odo',
#  '+1:word.lower():pp',
#  'word.lower():pp',
#  'word[-3:]:PP',
#  'word[-2:]:PP',
#  '-1:word.lower():pp',
#  '+1:word.lower():hacer',
#  'word.lower():hacer',
#  'word[-3:]:cer',
#  'word.lower():dinero',
#  '+1:word.lower():todo',
#  'word.lower():todo',
#  '-1:word.lower():todo',
#  'word.lower():ese',
#  'word[-3:]:ese',
#  '-1:word.lower():ese',
#  '+1:word.lower():sus',
#  'word.lower():sus',
#  'word[-2:]:us',
#  '+1:word.lower():amigos',
#  'word.lower():amigos',
#  'word[-3:]:gos',
#  '-1:word.lower():sus',
#  '-1:word.lower():amigos',
#  '-1:word.lower():convertido',
#  'word[-2:]:pa',
#  'word[-3:]:ena',
#  'word[-3:]:ros',
#  '+1:word.lower():cuando',
#  '-1:word.lower():cuando',
#  'word[-3:]:des',
#  '+1:word.lower():europa',
#  'word.lower():europa',
#  'word[-3:]:opa',
#  '+1:word.lower():occidental',
#  'word.lower():occidental',
#  '-1:word.lower():europa',
#  '+1:word.lower():urbanos',
#  'word.lower():urbanos',
#  'word[-3:]:A',
#  'word[-2:]:A',
#  'word[-3:]:cio',
#  'word[-3:]:var',
#  'word[-3:]:tas',
#  'word[-3:]:cas',
#  '+1:word.lower():pero',
#  'word.lower():pero',
#  '-1:word.lower():pero',
#  '+1:word.lower():tienen',
#  'word.lower():tienen',
#  'word[-3:]:nen',
#  '+1:word.lower():nada',
#  'word.lower():nada',
#  '-1:word.lower():nada',
#  '+1:word.lower():futuro',
#  'word.lower():futuro',
#  'word[-3:]:uro',
#  '-1:word.lower():futuro',
#  '+1:word.lower():ni',
#  'word[-2:]:ni',
#  '-1:word.lower():ni',
#  'word.lower():bienestar',
#  'word[-3:]:tar',
#  '-1:word.lower():bienestar',
#  'word[-3:]:ría',
#  'word[-2:]:ía',
#  '+1:word.lower():-',
#  '+1:postag:Fg',
#  '+1:postag[:2]:Fg',
#  '+1:word.lower():cantabria',
#  'word.lower():cantabria',
#  '-1:word.lower():-',
#  '-1:postag:Fg',
#  '-1:postag[:2]:Fg',
#  '+1:word.lower():fráncfort',
#  'word.lower():fráncfort',
#  'word[-3:]:ort',
#  'word[-2:]:rt',
#  '-1:word.lower():cantabria',
#  '-1:word.lower():fráncfort',
#  'word.lower():rfa',
#  'word[-3:]:RFA',
#  'word[-2:]:FA',
#  'word.lower():efecom',
#  'word[-3:]:COM',
#  'word[-2:]:OM',
#  '+1:word.lower():grupo',
#  'word.lower():grupo',
#  'word[-3:]:upo',
#  '+1:word.lower():alemán',
#  'word.lower():alemán',
#  'word[-3:]:mán',
#  '-1:word.lower():grupo',
#  '-1:word.lower():alemán',
#  'word[-3:]:nía',
#  '+1:word.lower():deutsche',
#  'word.lower():deutsche',
#  'word[-3:]:che',
#  'word[-2:]:he',
#  '-1:word.lower():telefonía',
#  '+1:word.lower():telekom',
#  'word.lower():telekom',
#  'word[-3:]:kom',
#  'word[-2:]:om',
#  '-1:word.lower():deutsche',
#  'word[-2:]:50',
#  'word.lower():ciento',
#  '-1:word.lower():ciento',
#  'word[-3:]:dor',
#  '+1:word.lower():suizo',
#  'word.lower():suizo',
#  'word[-3:]:izo',
#  'word[-2:]:zo',
#  '-1:word.lower():operador',
#  '+1:word.lower():telecomunicaciones',
#  'word.lower():telecomunicaciones',
#  'word.lower():multilink',
#  'word[-3:]:ink',
#  'word[-2:]:nk',
#  '+1:word.lower():hasta',
#  'word.lower():hasta',
#  'word.lower():ahora',
#  'word[-3:]:ora',
#  '-1:word.lower():hasta',
#  '-1:word.lower():ahora',
#  '+1:word.lower():france',
#  'word.lower():france',
#  'word[-3:]:nce',
#  'word[-2:]:ce',
#  '+1:word.lower():telecom',
#  'word.lower():telecom',
#  'word[-3:]:com',
#  '-1:word.lower():france',
#  '-1:word.lower():telecom',
#  'word[-3:]:rio',
#  'word.lower():informó',
#  'word[-3:]:rmó',
#  'word[-2:]:mó',
#  '+1:word.lower():hoy,',
#  '-1:word.lower():informó',
#  '+1:word.lower():jueves',
#  'word.lower():jueves',
#  'word[-3:]:ves',
#  '-1:word.lower():jueves',
#  'word.lower():compañía',
#  'word[-3:]:ñía',
#  '-1:word.lower():compañía',
#  'word.lower():consorcio',
#  '+1:word.lower():francés',
#  'word.lower():francés',
#  'word[-3:]:cés',
#  '-1:word.lower():consorcio',
#  '-1:word.lower():francés',
#  '+1:word.lower():participación',
#  'word.lower():participación',
#  '+1:word.lower():empresa',
#  'word.lower():empresa',
#  'word[-3:]:esa',
#  '+1:word.lower():mixta',
#  '-1:word.lower():empresa',
#  '+1:word.lower():británica',
#  'word.lower():británica',
#  '-1:word.lower():mixta',
#  'word.lower():metroholdings',
#  'word[-3:]:ngs',
#  'word[-2:]:gs',
#  '-1:word.lower():británica',
#  '+1:word.lower():fue',
#  'word.lower():fue',
#  '+1:word.lower():creada',
#  '-1:word.lower():fue',
#  'word.lower():1998',
#  'word[-3:]:998',
#  'word[-2:]:98',
#  '+1:word.lower():ofrece',
#  'word[-3:]:ece',
#  '+1:word.lower():servicios',
#  'word.lower():servicios',
#  '-1:word.lower():servicios',
#  'word.lower():suiza',
#  'word[-3:]:iza',
#  'word[-2:]:za',
#  '-1:word.lower():suiza',
#  '+1:word.lower():además',
#  'word.lower():además',
#  'word[-3:]:ner',
#  '+1:word.lower():red',
#  'word.lower():red',
#  'word[-2:]:ed',
#  '+1:word.lower():urbana',
#  '-1:word.lower():red',
#  '-1:word.lower():propia',
#  'word[-3:]:bra',
#  '+1:word.lower():calificó',
#  '+1:word.lower():esta',
#  '+1:word.lower():compra',
#  'word.lower():compra',
#  'word[-2:]:yo',
#  '+1:word.lower():precio',
#  'word.lower():precio',
#  '-1:word.lower():precio',
#  'word[-3:]:tro',
#  '+1:word.lower():paso',
#  '+1:word.lower():hacia',
#  '-1:word.lower():paso',
#  '-1:word.lower():hacia',
#  ...]

# %% [markdown]
# ## Evaluation
#
# There is much more O entities in data set, but we're more interested in other entities. To account for this we'll use averaged F1 score computed for all labels except for O. ``sklearn-crfsuite.metrics`` package provides some useful metrics for sequence classification task, including this one.

# %%
labels = list(crf.classes_)
labels.remove('O')
labels
# Out:
# ['B-LOC', 'B-ORG', 'B-PER', 'I-PER', 'B-MISC', 'I-ORG', 'I-LOC', 'I-MISC']

# %%
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred, 
                      average='weighted', labels=labels)
# Out:
# 0.7964686316443963

# %% [markdown]
# Inspect per-class results in more detail:

# %%
# group B and I results
sorted_labels = sorted(
    labels, 
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#        B-LOC      0.810     0.784     0.797      1084
#        I-LOC      0.690     0.637     0.662       325
#       B-MISC      0.731     0.569     0.640       339
#       I-MISC      0.699     0.589     0.639       557
#        B-ORG      0.807     0.832     0.820      1400
#        I-ORG      0.852     0.786     0.818      1104
#        B-PER      0.850     0.884     0.867       735
#        I-PER      0.893     0.943     0.917       634
#
#    micro avg      0.813     0.787     0.799      6178
#    macro avg      0.791     0.753     0.770      6178
# weighted avg      0.809     0.787     0.796      6178

# %% [markdown]
# ## Hyperparameter Optimization
#
# To improve quality try to select regularization parameters using randomized search and 3-fold cross-validation.
#
# I takes quite a lot of CPU time and RAM (we're fitting a model ``50 * 3 = 150`` times), so grab a tea and be patient, or reduce n_iter in RandomizedSearchCV, or fit model only on a subset of training data.

# %%
## %%time
# define fixed parameters and parameters to search
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    max_iterations=100, 
    all_possible_transitions=True
)
params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05),
}

# use the same metric for evaluation
f1_scorer = make_scorer(metrics.flat_f1_score, 
                        average='weighted', labels=labels)

# search
rs = RandomizedSearchCV(crf, params_space, 
                        cv=3,   for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))    

print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(30))

print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-30:])
                        verbose=1, 
                        n_jobs=-1, 
                        n_iter=50, 
                        scoring=f1_scorer)
rs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 41.9min finished
# RandomizedSearchCV(cv=3, error_score='raise-deprecating',
#                    estimator=CRF(algorithm='lbfgs', all_possible_states=None,
#                                  all_possible_transitions=True, averaging=None,
#                                  c=None, c1=None, c2=None,
#                                  calibration_candidates=None,
#                                  calibration_eta=None,
#                                  calibration_max_trials=None,
#                                  calibration_rate=None,
#                                  calibration_samples=None, delta=None,
#                                  epsilon=None, error_sensitive=None,...
#                    param_distributions={'c1': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f97b78d0898>,
#                                         'c2': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f97b78d0a90>},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False,
#                    scoring=make_scorer(flat_f1_score, average=weighted, labels=['B-LOC', 'B-ORG', 'B-PER', 'I-PER', 'B-MISC', 'I-ORG', 'I-LOC', 'I-MISC']),
#                    verbose=1)

# %% [markdown]
# Best result:

# %%
# crf = rs.best_estimator_
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))
# Out:
# best params: {'c1': 0.1626142476992158, 'c2': 0.00992258748099264}
# best CV score: 0.749065332909574
# model size: 1.15M

# %%
[s.parameters['c1'] for s in rs.]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-0ee3cd22d03b> in <module>
# ----> 1 [s.parameters['c1'] for s in rs.scoring]
#
# TypeError: '_PredictScorer' object is not iterable

# %% [markdown]
# ### Check parameter space
#
# A chart which shows which ``c1`` and ``c2`` values have RandomizedSearchCV checked. Red color means better results, blue means worse.

# %%
_x = [s.parameters['c1'] for s in rs.]
_y = [s.parameters['c2'] for s in rs.grid_scores_]
_c = [s.mean_validation_score for s in rs.grid_scores_]

fig = plt.figure()
fig.set_size_inches(12, 12)
ax = plt.gca()
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlabel('C1')
ax.set_ylabel('C2')
ax.set_title("Randomized Hyperparameter Search CV Results (min={:0.3}, max={:0.3})".format(
    min(_c), max(_c)
))

ax.scatter(_x, _y, c=_c, s=60, alpha=0.9, edgecolors=[0,0,0])

print("Dark blue => {:0.4}, dark red => {:0.4}".format(min(_c), max(_c)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-a398442260ed> in <module>
# ----> 1 _x = [s.parameters['c1'] for s in rs.grid_scores_]
#       2 _y = [s.parameters['c2'] for s in rs.grid_scores_]
#       3 _c = [s.mean_validation_score for s in rs.grid_scores_]
#       4
#       5 fig = plt.figure()
#
# AttributeError: 'RandomizedSearchCV' object has no attribute 'grid_scores_'

# %% [markdown]
# ## Check best estimator on our test data
#
# As you can see, quality is improved.

# %%
crf = rs.best_estimator_
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred, 
                      average='weighted', labels=labels)
# Out:
# 0.7944628836021157

# %%
crf = rs.best_estimator_
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#        B-LOC      0.800     0.785     0.792      1084
#        I-LOC      0.685     0.662     0.673       325
#       B-MISC      0.709     0.560     0.626       339
#       I-MISC      0.698     0.592     0.641       557
#        B-ORG      0.810     0.829     0.820      1400
#        I-ORG      0.857     0.778     0.816      1104
#        B-PER      0.845     0.880     0.862       735
#        I-PER      0.887     0.943     0.914       634
#
#    micro avg      0.809     0.785     0.797      6178
#    macro avg      0.786     0.754     0.768      6178
# weighted avg      0.806     0.785     0.794      6178

# %% [markdown]
# ## Let's check what classifier learned

# %%
from collections import Counter

def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))

print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common(20))

print("\nTop unlikely transitions:")
print_transitions(Counter(crf.transition_features_).most_common()[-20:])
# Out:
# Top likely transitions:
# B-ORG  -> I-ORG   7.500912
# I-ORG  -> I-ORG   7.206322
# B-MISC -> I-MISC  6.833142
# I-MISC -> I-MISC  6.753222
# B-PER  -> I-PER   6.404557
# B-LOC  -> I-LOC   5.696274
# I-LOC  -> I-LOC   4.877422
# I-PER  -> I-PER   4.709231
# O      -> O       3.784430
# O      -> B-ORG   2.754974
# O      -> B-PER   2.549453
# O      -> B-LOC   1.846099
# O      -> B-MISC  1.804584
# B-LOC  -> B-LOC   0.578393
# B-ORG  -> O       0.325175
# I-PER  -> B-LOC   0.300667
# B-MISC -> B-ORG   0.298525
# B-ORG  -> B-LOC   0.266688
# B-LOC  -> B-PER   -0.046324
# B-MISC -> O       -0.143646
#
# Top unlikely transitions:
# I-LOC  -> B-MISC  -1.976574
# I-MISC -> I-PER   -2.008671
# B-ORG  -> B-ORG   -2.107974
# I-ORG  -> B-LOC   -2.199630
# I-MISC -> B-LOC   -2.240108
# I-ORG  -> I-PER   -2.272384
# B-PER  -> B-MISC  -2.325289
# I-PER  -> I-LOC   -2.455352
# I-ORG  -> B-MISC  -2.486495
# I-PER  -> B-ORG   -2.512129
# I-ORG  -> I-LOC   -2.536158
# I-MISC -> I-LOC   -2.557052
# B-ORG  -> B-MISC  -2.581202
# B-PER  -> B-PER   -2.825385
# I-PER  -> B-MISC  -2.966281
# B-MISC -> B-MISC  -3.028264
# O      -> I-MISC  -5.136612
# O      -> I-ORG   -5.230042
# O      -> I-PER   -5.357097
# O      -> I-LOC   -5.968293

# %% [markdown]
# We can see that, for example, it is very likely that the beginning of an organization name (B-ORG) will be followed by a token inside organization name (I-ORG), but transitions to I-ORG from tokens with other labels are penalized.
#
# Check the state features:

# %%
crf.state_features_
# Out:
# {('bias', 'B-LOC'): -0.632968,
#  ('bias', 'O'): 4.05394,
#  ('bias', 'B-ORG'): -1.246552,
#  ('bias', 'B-PER'): -0.596076,
#  ('bias', 'I-PER'): -1.591598,
#  ('bias', 'B-MISC'): -0.369917,
#  ('bias', 'I-ORG'): -1.627245,
#  ('bias', 'I-LOC'): -0.262979,
#  ('bias', 'I-MISC'): -0.391216,
#  ('word.lower():melbourne', 'B-LOC'): 1.685295,
#  ('word.lower():melbourne', 'I-MISC'): 0.54326,
#  ('word[-3:]:rne', 'B-LOC'): 0.551362,
#  ('word[-3:]:rne', 'I-MISC'): 0.503875,
#  ('word[-2:]:ne', 'B-LOC'): 0.008109,
#  ('word[-2:]:ne', 'O'): 0.833204,
#  ('word[-2:]:ne', 'B-ORG'): 0.06339,
#  ('word[-2:]:ne', 'B-PER'): 1.048272,
#  ('word.isupper()', 'B-LOC'): 1.00164,
#  ('word.isupper()', 'O'): -6.248543,
#  ('word.isupper()', 'B-ORG'): 5.178607,
#  ('word.isupper()', 'B-PER'): 1.165861,
#  ('word.isupper()', 'I-PER'): 0.274261,
#  ('word.isupper()', 'B-MISC'): 3.698361,
#  ('word.isupper()', 'I-ORG'): 3.294302,
#  ('word.isupper()', 'I-LOC'): 0.34496,
#  ('word.isupper()', 'I-MISC'): -0.078701,
#  ('word.istitle()', 'B-LOC'): 2.538079,
#  ('word.istitle()', 'O'): -9.516203,
#  ('word.istitle()', 'B-ORG'): 1.79738,
#  ('word.istitle()', 'B-PER'): 2.25439,
#  ('word.istitle()', 'I-PER'): 1.722031,
#  ('word.istitle()', 'B-MISC'): 1.729932,
#  ('word.istitle()', 'I-ORG'): 0.436356,
#  ('word.istitle()', 'I-LOC'): 0.909577,
#  ('word.istitle()', 'I-MISC'): -0.919685,
#  ('word.isdigit()', 'B-LOC'): -0.023977,
#  ('word.isdigit()', 'O'): -0.634579,
#  ('word.isdigit()', 'B-ORG'): 0.69895,
#  ('word.isdigit()', 'B-MISC'): -1.695102,
#  ('word.isdigit()', 'I-ORG'): 3.499479,
#  ('word.isdigit()', 'I-LOC'): -0.003448,
#  ('word.isdigit()', 'I-MISC'): 0.874713,
#  ('postag:NP', 'B-LOC'): 0.414437,
#  ('postag:NP', 'O'): -2.073683,
#  ('postag:NP', 'B-ORG'): 0.750106,
#  ('postag:NP', 'B-PER'): 0.92411,
#  ('postag[:2]:NP', 'B-LOC'): 0.414437,
#  ('postag[:2]:NP', 'O'): -2.073683,
#  ('postag[:2]:NP', 'B-ORG'): 0.750106,
#  ('postag[:2]:NP', 'B-PER'): 0.92411,
#  ('BOS', 'B-LOC'): 0.767068,
#  ('BOS', 'O'): 5.648352,
#  ('BOS', 'B-ORG'): 0.087594,
#  ('BOS', 'B-PER'): 1.309907,
#  ('BOS', 'B-MISC'): 0.224497,
#  ('BOS', 'I-LOC'): -2.231729,
#  ('+1:word.lower():(', 'B-LOC'): 0.366471,
#  ('+1:word.lower():(', 'O'): -0.597908,
#  ('+1:word.lower():(', 'B-ORG'): -0.341113,
#  ('+1:word.lower():(', 'B-PER'): 0.001801,
#  ('+1:word.lower():(', 'I-PER'): 0.241268,
#  ('+1:word.lower():(', 'B-MISC'): -0.240629,
#  ('+1:word.lower():(', 'I-ORG'): 0.284745,
#  ('+1:word.lower():(', 'I-LOC'): 0.174102,
#  ('+1:word.lower():(', 'I-MISC'): -0.103148,
#  ('+1:word.istitle()', 'B-LOC'): 0.522013,
#  ('+1:word.istitle()', 'O'): 0.024005,
#  ('+1:word.istitle()', 'B-ORG'): 0.122728,
#  ('+1:word.istitle()', 'B-PER'): 1.10853,
#  ('+1:word.istitle()', 'I-PER'): -0.029458,
#  ('+1:word.istitle()', 'B-MISC'): 0.327344,
#  ('+1:word.istitle()', 'I-ORG'): 0.272056,
#  ('+1:word.istitle()', 'I-LOC'): 0.700514,
#  ('+1:word.istitle()', 'I-MISC'): -0.276452,
#  ('+1:word.isupper()', 'B-LOC'): -0.772195,
#  ('+1:word.isupper()', 'O'): 0.484148,
#  ('+1:word.isupper()', 'B-ORG'): -0.48355,
#  ('+1:word.isupper()', 'B-PER'): 0.89826,
#  ('+1:word.isupper()', 'I-PER'): 0.037852,
#  ('+1:word.isupper()', 'B-MISC'): 1.325341,
#  ('+1:word.isupper()', 'I-ORG'): -1.878494,
#  ('+1:word.isupper()', 'I-LOC'): -0.535302,
#  ('+1:word.isupper()', 'I-MISC'): -0.882057,
#  ('+1:postag:Fpa', 'B-LOC'): 0.366471,
#  ('+1:postag:Fpa', 'O'): -0.597908,
#  ('+1:postag:Fpa', 'B-ORG'): -0.341113,
#  ('+1:postag:Fpa', 'B-PER'): 0.001801,
#  ('+1:postag:Fpa', 'I-PER'): 0.241268,
#  ('+1:postag:Fpa', 'B-MISC'): -0.240629,
#  ('+1:postag:Fpa', 'I-ORG'): 0.284745,
#  ('+1:postag:Fpa', 'I-LOC'): 0.174102,
#  ('+1:postag:Fpa', 'I-MISC'): -0.103148,
#  ('+1:postag[:2]:Fp', 'B-LOC'): 0.76302,
#  ('+1:postag[:2]:Fp', 'O'): 0.273445,
#  ('+1:postag[:2]:Fp', 'B-ORG'): -0.106071,
#  ('+1:postag[:2]:Fp', 'B-PER'): -0.114723,
#  ('+1:postag[:2]:Fp', 'I-PER'): 0.156212,
#  ('+1:postag[:2]:Fp', 'B-MISC'): -0.014098,
#  ('+1:postag[:2]:Fp', 'I-ORG'): -0.016707,
#  ('+1:postag[:2]:Fp', 'I-LOC'): 0.283647,
#  ('+1:postag[:2]:Fp', 'I-MISC'): -0.101492,
#  ('word.lower():(', 'O'): 0.450467,
#  ('word[-3:]:(', 'O'): 0.450467,
#  ('word[-2:]:(', 'O'): 0.450467,
#  ('postag:Fpa', 'O'): 0.450467,
#  ('postag[:2]:Fp', 'B-LOC'): 1.12563,
#  ('postag[:2]:Fp', 'O'): 4.968334,
#  ('-1:word.istitle()', 'B-LOC'): -0.664665,
#  ('-1:word.istitle()', 'O'): 1.575348,
#  ('-1:word.istitle()', 'B-ORG'): 0.704509,
#  ('-1:word.istitle()', 'B-PER'): 0.709154,
#  ('-1:word.istitle()', 'I-PER'): 3.007932,
#  ('-1:word.istitle()', 'B-MISC'): 0.774749,
#  ('-1:word.istitle()', 'I-ORG'): 2.173106,
#  ('-1:word.istitle()', 'I-LOC'): 0.602376,
#  ('-1:word.istitle()', 'I-MISC'): 1.419217,
#  ('-1:word.isupper()', 'B-LOC'): 2.04616,
#  ('-1:word.isupper()', 'O'): 2.809731,
#  ('-1:word.isupper()', 'B-ORG'): -1.477424,
#  ('-1:word.isupper()', 'B-PER'): -0.073675,
#  ('-1:word.isupper()', 'I-PER'): 0.4811,
#  ('-1:word.isupper()', 'B-MISC'): -2.931011,
#  ('-1:word.isupper()', 'I-ORG'): -2.095252,
#  ('-1:word.isupper()', 'I-LOC'): -0.688752,
#  ('-1:word.isupper()', 'I-MISC'): 0.188781,
#  ('-1:postag:NP', 'O'): 0.602017,
#  ('-1:postag:NP', 'I-PER'): 0.394934,
#  ('-1:postag:NP', 'I-ORG'): -0.626552,
#  ('-1:postag:NP', 'I-MISC'): 0.015902,
#  ('-1:postag[:2]:NP', 'O'): 0.602017,
#  ('-1:postag[:2]:NP', 'I-PER'): 0.394934,
#  ('-1:postag[:2]:NP', 'I-ORG'): -0.626552,
#  ('-1:postag[:2]:NP', 'I-MISC'): 0.015902,
#  ('+1:postag:NP', 'O'): 0.491262,
#  ('+1:postag:NP', 'B-ORG'): 0.03463,
#  ('+1:postag:NP', 'B-PER'): 1.536367,
#  ('+1:postag[:2]:NP', 'O'): 0.491262,
#  ('+1:postag[:2]:NP', 'B-ORG'): 0.03463,
#  ('+1:postag[:2]:NP', 'B-PER'): 1.536367,
#  ('word.lower():australia', 'B-LOC'): 0.617588,
#  ('word.lower():australia', 'B-ORG'): 0.133653,
#  ('word[-3:]:lia', 'B-LOC'): 0.229993,
#  ('word[-3:]:lia', 'O'): -0.72153,
#  ('word[-3:]:lia', 'B-ORG'): -0.054108,
#  ('word[-3:]:lia', 'B-PER'): 0.001692,
#  ('word[-3:]:lia', 'I-PER'): -1.621264,
#  ('word[-3:]:lia', 'I-ORG'): 0.341287,
#  ('word[-3:]:lia', 'I-MISC'): -0.00385,
#  ('word[-2:]:ia', 'B-LOC'): 0.918248,
#  ('word[-2:]:ia', 'O'): -0.501565,
#  ('word[-2:]:ia', 'B-ORG'): 0.734732,
#  ('word[-2:]:ia', 'B-PER'): -1.962529,
#  ('word[-2:]:ia', 'I-PER'): -0.268852,
#  ('word[-2:]:ia', 'B-MISC'): -0.383672,
#  ('word[-2:]:ia', 'I-ORG'): 0.005741,
#  ('word[-2:]:ia', 'I-LOC'): -0.226132,
#  ('word[-2:]:ia', 'I-MISC'): 0.037437,
#  ('-1:word.lower():(', 'B-LOC'): 0.489249,
#  ('-1:word.lower():(', 'O'): -0.000211,
#  ('-1:word.lower():(', 'B-ORG'): 0.239425,
#  ('-1:word.lower():(', 'B-PER'): -0.374244,
#  ('-1:word.lower():(', 'B-MISC'): -0.019889,
#  ('-1:postag:Fpa', 'B-LOC'): 0.489249,
#  ('-1:postag:Fpa', 'O'): -0.000211,
#  ('-1:postag:Fpa', 'B-ORG'): 0.239425,
#  ('-1:postag:Fpa', 'B-PER'): -0.374244,
#  ('-1:postag:Fpa', 'B-MISC'): -0.019889,
#  ('-1:postag[:2]:Fp', 'B-LOC'): 0.555716,
#  ('-1:postag[:2]:Fp', 'O'): 0.617502,
#  ('-1:postag[:2]:Fp', 'B-ORG'): 0.120885,
#  ('-1:postag[:2]:Fp', 'B-PER'): -0.115658,
#  ('-1:postag[:2]:Fp', 'B-MISC'): -0.107044,
#  ('+1:word.lower():)', 'B-LOC'): 0.157415,
#  ('+1:word.lower():)', 'O'): 0.05459,
#  ('+1:word.lower():)', 'B-ORG'): -0.057284,
#  ('+1:word.lower():)', 'B-PER'): -0.35072,
#  ('+1:word.lower():)', 'I-PER'): -0.073639,
#  ('+1:word.lower():)', 'B-MISC'): -0.08359,
#  ('+1:word.lower():)', 'I-ORG'): -0.184365,
#  ('+1:word.lower():)', 'I-LOC'): 0.472952,
#  ('+1:word.lower():)', 'I-MISC'): 0.225823,
#  ('+1:postag:Fpt', 'B-LOC'): 0.157415,
#  ('+1:postag:Fpt', 'O'): 0.05459,
#  ('+1:postag:Fpt', 'B-ORG'): -0.057284,
#  ('+1:postag:Fpt', 'B-PER'): -0.35072,
#  ('+1:postag:Fpt', 'I-PER'): -0.073639,
#  ('+1:postag:Fpt', 'B-MISC'): -0.08359,
#  ('+1:postag:Fpt', 'I-ORG'): -0.184365,
#  ('+1:postag:Fpt', 'I-LOC'): 0.472952,
#  ('+1:postag:Fpt', 'I-MISC'): 0.225823,
#  ('word.lower():)', 'O'): 0.112492,
#  ('word[-3:]:)', 'O'): 0.112492,
#  ('word[-2:]:)', 'O'): 0.112492,
#  ('postag:Fpt', 'O'): 0.112492,
#  ('+1:word.lower():,', 'B-LOC'): 0.340929,
#  ('+1:word.lower():,', 'O'): 0.005634,
#  ('+1:word.lower():,', 'B-ORG'): 0.098858,
#  ('+1:word.lower():,', 'B-PER'): -0.005854,
#  ('+1:word.lower():,', 'I-PER'): 0.362598,
#  ('+1:word.lower():,', 'B-MISC'): 0.040075,
#  ('+1:word.lower():,', 'I-ORG'): 0.119554,
#  ('+1:word.lower():,', 'I-LOC'): 0.226614,
#  ('+1:word.lower():,', 'I-MISC'): 0.212395,
#  ('+1:postag:Fc', 'B-LOC'): 0.340929,
#  ('+1:postag:Fc', 'O'): 0.005634,
#  ('+1:postag:Fc', 'B-ORG'): 0.098858,
#  ('+1:postag:Fc', 'B-PER'): -0.005854,
#  ('+1:postag:Fc', 'I-PER'): 0.362598,
#  ('+1:postag:Fc', 'B-MISC'): 0.040075,
#  ('+1:postag:Fc', 'I-ORG'): 0.119554,
#  ('+1:postag:Fc', 'I-LOC'): 0.226614,
#  ('+1:postag:Fc', 'I-MISC'): 0.212395,
#  ('+1:postag[:2]:Fc', 'B-LOC'): 0.340929,
#  ('+1:postag[:2]:Fc', 'O'): 0.005634,
#  ('+1:postag[:2]:Fc', 'B-ORG'): 0.098858,
#  ('+1:postag[:2]:Fc', 'B-PER'): -0.005854,
#  ('+1:postag[:2]:Fc', 'I-PER'): 0.362598,
#  ('+1:postag[:2]:Fc', 'B-MISC'): 0.040075,
#  ('+1:postag[:2]:Fc', 'I-ORG'): 0.119554,
#  ('+1:postag[:2]:Fc', 'I-LOC'): 0.226614,
#  ('+1:postag[:2]:Fc', 'I-MISC'): 0.212395,
#  ('word.lower():,', 'O'): 1.715111,
#  ('word[-3:]:,', 'O'): 1.715111,
#  ('word[-2:]:,', 'O'): 1.715111,
#  ('postag:Fc', 'O'): 1.715111,
#  ('postag[:2]:Fc', 'O'): 1.715111,
#  ('-1:word.lower():)', 'B-LOC'): 0.353355,
#  ('-1:word.lower():)', 'O'): 0.275209,
#  ('-1:word.lower():)', 'B-ORG'): -0.938192,
#  ('-1:word.lower():)', 'B-PER'): 0.223132,
#  ('-1:word.lower():)', 'B-MISC'): -1.166801,
#  ('-1:postag:Fpt', 'B-LOC'): 0.353355,
#  ('-1:postag:Fpt', 'O'): 0.275209,
#  ('-1:postag:Fpt', 'B-ORG'): -0.938192,
#  ('-1:postag:Fpt', 'B-PER'): 0.223132,
#  ('-1:postag:Fpt', 'B-MISC'): -1.166801,
#  ('+1:word.lower():25', 'B-LOC'): 2.04116,
#  ('+1:word.lower():25', 'I-LOC'): 1.971979,
#  ('+1:postag:Z', 'B-LOC'): -0.444403,
#  ('+1:postag:Z', 'O'): -0.23716,
#  ('+1:postag:Z', 'B-ORG'): 0.234531,
#  ('+1:postag:Z', 'B-PER'): -0.98113,
#  ('+1:postag:Z', 'I-PER'): -1.099464,
#  ('+1:postag:Z', 'B-MISC'): 0.753894,
#  ('+1:postag:Z', 'I-ORG'): -0.056142,
#  ('+1:postag:Z', 'I-LOC'): -0.238121,
#  ('+1:postag:Z', 'I-MISC'): 0.386894,
#  ('+1:postag[:2]:Z', 'B-LOC'): -0.444403,
#  ('+1:postag[:2]:Z', 'O'): -0.23716,
#  ('+1:postag[:2]:Z', 'B-ORG'): 0.234531,
#  ('+1:postag[:2]:Z', 'B-PER'): -0.98113,
#  ('+1:postag[:2]:Z', 'I-PER'): -1.099464,
#  ('+1:postag[:2]:Z', 'B-MISC'): 0.753894,
#  ('+1:postag[:2]:Z', 'I-ORG'): -0.056142,
#  ('+1:postag[:2]:Z', 'I-LOC'): -0.238121,
#  ('+1:postag[:2]:Z', 'I-MISC'): 0.386894,
#  ('word[-2:]:25', 'O'): 0.82038,
#  ('postag:Z', 'B-LOC'): -0.411505,
#  ('postag:Z', 'O'): 0.406024,
#  ('postag:Z', 'B-ORG'): -1.181224,
#  ('postag:Z', 'B-MISC'): 1.865176,
#  ('postag:Z', 'I-ORG'): -0.511072,
#  ('postag:Z', 'I-LOC'): -0.177964,
#  ('postag:Z', 'I-MISC'): 0.245627,
#  ('postag[:2]:Z', 'B-LOC'): -0.411505,
#  ('postag[:2]:Z', 'O'): 0.406024,
#  ('postag[:2]:Z', 'B-ORG'): -1.181224,
#  ('postag[:2]:Z', 'B-MISC'): 1.865176,
#  ('postag[:2]:Z', 'I-ORG'): -0.511072,
#  ('postag[:2]:Z', 'I-LOC'): -0.177964,
#  ('postag[:2]:Z', 'I-MISC'): 0.245627,
#  ('-1:word.lower():,', 'B-LOC'): 0.09736,
#  ('-1:word.lower():,', 'O'): -0.032753,
#  ('-1:word.lower():,', 'B-ORG'): 0.141634,
#  ('-1:word.lower():,', 'B-PER'): 0.411078,
#  ('-1:word.lower():,', 'B-MISC'): 0.001277,
#  ('-1:postag:Fc', 'B-LOC'): 0.09736,
#  ('-1:postag:Fc', 'O'): -0.032753,
#  ('-1:postag:Fc', 'B-ORG'): 0.141634,
#  ('-1:postag:Fc', 'B-PER'): 0.411078,
#  ('-1:postag:Fc', 'B-MISC'): 0.001277,
#  ('-1:postag[:2]:Fc', 'B-LOC'): 0.09736,
#  ('-1:postag[:2]:Fc', 'O'): -0.032753,
#  ('-1:postag[:2]:Fc', 'B-ORG'): 0.141634,
#  ('-1:postag[:2]:Fc', 'B-PER'): 0.411078,
#  ('-1:postag[:2]:Fc', 'B-MISC'): 0.001277,
#  ('+1:postag:NC', 'B-LOC'): -0.353921,
#  ('+1:postag:NC', 'O'): 0.765959,
#  ('+1:postag:NC', 'B-ORG'): -0.302018,
#  ('+1:postag:NC', 'B-PER'): -0.124761,
#  ('+1:postag:NC', 'I-PER'): -0.326332,
#  ('+1:postag:NC', 'B-MISC'): -0.106586,
#  ('+1:postag:NC', 'I-ORG'): -0.401618,
#  ('+1:postag:NC', 'I-LOC'): -0.138782,
#  ('+1:postag:NC', 'I-MISC'): -0.025279,
#  ('+1:postag[:2]:NC', 'B-LOC'): -0.353921,
#  ('+1:postag[:2]:NC', 'O'): 0.765959,
#  ('+1:postag[:2]:NC', 'B-ORG'): -0.302018,
#  ('+1:postag[:2]:NC', 'B-PER'): -0.124761,
#  ('+1:postag[:2]:NC', 'I-PER'): -0.326332,
#  ('+1:postag[:2]:NC', 'B-MISC'): -0.106586,
#  ('+1:postag[:2]:NC', 'I-ORG'): -0.401618,
#  ('+1:postag[:2]:NC', 'I-LOC'): -0.138782,
#  ('+1:postag[:2]:NC', 'I-MISC'): -0.025279,
#  ('word.lower():may', 'O'): 2.189798,
#  ('word[-2:]:ay', 'O'): 0.463624,
#  ('word[-2:]:ay', 'B-ORG'): 0.315281,
#  ('word[-2:]:ay', 'B-PER'): -0.289173,
#  ('postag:NC', 'B-LOC'): 0.128491,
#  ('postag:NC', 'O'): -0.87302,
#  ('postag:NC', 'B-ORG'): 0.013322,
#  ('postag:NC', 'B-PER'): 0.346224,
#  ('postag:NC', 'I-PER'): 0.343131,
#  ('postag:NC', 'B-MISC'): -0.241751,
#  ('postag:NC', 'I-ORG'): 0.381765,
#  ('postag:NC', 'I-LOC'): 0.299422,
#  ('postag:NC', 'I-MISC'): 0.502419,
#  ('postag[:2]:NC', 'B-LOC'): 0.128491,
#  ('postag[:2]:NC', 'O'): -0.87302,
#  ('postag[:2]:NC', 'B-ORG'): 0.013322,
#  ('postag[:2]:NC', 'B-PER'): 0.346224,
#  ('postag[:2]:NC', 'I-PER'): 0.343131,
#  ('postag[:2]:NC', 'B-MISC'): -0.241751,
#  ('postag[:2]:NC', 'I-ORG'): 0.381765,
#  ('postag[:2]:NC', 'I-LOC'): 0.299422,
#  ('postag[:2]:NC', 'I-MISC'): 0.502419,
#  ('-1:word.lower():25', 'O'): 1.930066,
#  ('-1:postag:Z', 'B-LOC'): 0.639876,
#  ('-1:postag:Z', 'O'): 0.391838,
#  ('-1:postag:Z', 'B-ORG'): 0.298915,
#  ('-1:postag:Z', 'B-PER'): 0.025209,
#  ('-1:postag:Z', 'B-MISC'): -0.642576,
#  ('-1:postag:Z', 'I-ORG'): -0.978265,
#  ('-1:postag:Z', 'I-MISC'): -0.251008,
#  ('-1:postag[:2]:Z', 'B-LOC'): 0.639876,
#  ('-1:postag[:2]:Z', 'O'): 0.391838,
#  ('-1:postag[:2]:Z', 'B-ORG'): 0.298915,
#  ('-1:postag[:2]:Z', 'B-PER'): 0.025209,
#  ('-1:postag[:2]:Z', 'B-MISC'): -0.642576,
#  ('-1:postag[:2]:Z', 'I-ORG'): -0.978265,
#  ('-1:postag[:2]:Z', 'I-MISC'): -0.251008,
#  ('-1:postag:NC', 'B-LOC'): -0.221837,
#  ('-1:postag:NC', 'O'): 0.258167,
#  ('-1:postag:NC', 'B-ORG'): -0.154569,
#  ('-1:postag:NC', 'B-PER'): -0.146839,
#  ('-1:postag:NC', 'I-PER'): 0.275648,
#  ('-1:postag:NC', 'B-MISC'): 0.236184,
#  ('-1:postag:NC', 'I-ORG'): -0.037041,
#  ('-1:postag:NC', 'I-LOC'): 0.240917,
#  ('-1:postag:NC', 'I-MISC'): 0.302602,
#  ('-1:postag[:2]:NC', 'B-LOC'): -0.221837,
#  ('-1:postag[:2]:NC', 'O'): 0.258167,
#  ('-1:postag[:2]:NC', 'B-ORG'): -0.154569,
#  ('-1:postag[:2]:NC', 'B-PER'): -0.146839,
#  ('-1:postag[:2]:NC', 'I-PER'): 0.275648,
#  ('-1:postag[:2]:NC', 'B-MISC'): 0.236184,
#  ('-1:postag[:2]:NC', 'I-ORG'): -0.037041,
#  ('-1:postag[:2]:NC', 'I-LOC'): 0.240917,
#  ('-1:postag[:2]:NC', 'I-MISC'): 0.302602,
#  ('word.lower():efe', 'O'): -0.211334,
#  ('word.lower():efe', 'B-ORG'): 3.308774,
#  ('word.lower():efe', 'I-ORG'): 0.059015,
#  ('word[-3:]:EFE', 'O'): 1.210484,
#  ('word[-3:]:EFE', 'B-ORG'): 1.223591,
#  ('word[-2:]:FE', 'O'): -0.296267,
#  ('word[-2:]:FE', 'B-ORG'): 1.564761,
#  ('-1:word.lower():efe', 'B-LOC'): 3.121156,
#  ('-1:word.lower():efe', 'O'): 1.620239,
#  ('-1:word.lower():efe', 'B-PER'): 5.099275,
#  ('-1:word.lower():efe', 'B-MISC'): 4.835961,
#  ('+1:word.lower():.', 'B-LOC'): -0.039606,
#  ('+1:word.lower():.', 'O'): 0.079758,
#  ('+1:word.lower():.', 'B-ORG'): -0.027774,
#  ('+1:word.lower():.', 'B-PER'): -0.024608,
#  ('+1:word.lower():.', 'I-PER'): 0.240094,
#  ('+1:word.lower():.', 'B-MISC'): 0.018785,
#  ('+1:word.lower():.', 'I-ORG'): -0.107726,
#  ('+1:word.lower():.', 'I-LOC'): 0.044756,
#  ('+1:word.lower():.', 'I-MISC'): 0.122493,
#  ('+1:postag:Fp', 'B-LOC'): -0.039606,
#  ('+1:postag:Fp', 'O'): 0.079758,
#  ('+1:postag:Fp', 'B-ORG'): -0.027774,
#  ('+1:postag:Fp', 'B-PER'): -0.024608,
#  ('+1:postag:Fp', 'I-PER'): 0.240094,
#  ('+1:postag:Fp', 'B-MISC'): 0.018785,
#  ('+1:postag:Fp', 'I-ORG'): -0.107726,
#  ('+1:postag:Fp', 'I-LOC'): 0.044756,
#  ('+1:postag:Fp', 'I-MISC'): 0.122493,
#  ('word.lower():.', 'B-LOC'): 1.466003,
#  ('word.lower():.', 'O'): 1.207409,
#  ('word[-3:]:.', 'B-LOC'): 1.466003,
#  ('word[-3:]:.', 'O'): 1.207409,
#  ('word[-2:]:.', 'B-LOC'): 1.466003,
#  ('word[-2:]:.', 'O'): 1.207409,
#  ('postag:Fp', 'B-LOC'): 1.466003,
#  ('postag:Fp', 'O'): 1.207409,
#  ('EOS', 'B-LOC'): 1.546685,
#  ('EOS', 'O'): 1.417718,
#  ('EOS', 'I-MISC'): 0.911633,
#  ('word.lower():-', 'O'): 0.936182,
#  ('word[-3:]:-', 'O'): 0.936182,
#  ('word[-2:]:-', 'O'): 0.936182,
#  ('postag:Fg', 'O'): 0.936182,
#  ('postag[:2]:Fg', 'O'): 0.936182,
#  ('word.lower():el', 'B-LOC'): -1.971531,
#  ('word.lower():el', 'O'): 0.666496,
#  ('word.lower():el', 'B-ORG'): -0.006139,
#  ('word.lower():el', 'I-PER'): -0.237551,
#  ('word.lower():el', 'B-MISC'): -0.047721,
#  ('word.lower():el', 'I-ORG'): -0.004881,
#  ('word.lower():el', 'I-LOC'): -0.141362,
#  ('word.lower():el', 'I-MISC'): 0.335477,
#  ('word[-3:]:El', 'B-LOC'): 0.023649,
#  ('word[-3:]:El', 'O'): 1.971097,
#  ('word[-3:]:El', 'B-ORG'): -0.595163,
#  ('word[-3:]:El', 'B-PER'): 0.05959,
#  ('word[-3:]:El', 'I-PER'): -0.169789,
#  ('word[-3:]:El', 'B-MISC'): -0.334545,
#  ('word[-3:]:El', 'I-ORG'): -0.408847,
#  ('word[-3:]:El', 'I-MISC'): 0.023746,
#  ('word[-2:]:El', 'B-LOC'): 2.921777,
#  ('word[-2:]:El', 'O'): 1.967742,
#  ('word[-2:]:El', 'B-ORG'): -0.734037,
#  ('word[-2:]:El', 'I-PER'): -0.170355,
#  ('word[-2:]:El', 'B-MISC'): -0.427447,
#  ('word[-2:]:El', 'I-ORG'): -0.425955,
#  ('word[-2:]:El', 'I-MISC'): 0.012946,
#  ('postag:DA', 'B-LOC'): -0.287413,
#  ('postag:DA', 'O'): 0.713788,
#  ('postag:DA', 'B-ORG'): -0.275585,
#  ('postag:DA', 'B-PER'): -2.557981,
#  ('postag:DA', 'I-PER'): 0.387232,
#  ('postag:DA', 'B-MISC'): -0.398395,
#  ('postag:DA', 'I-ORG'): 0.049446,
#  ('postag:DA', 'I-LOC'): 0.301361,
#  ('postag:DA', 'I-MISC'): 0.124345,
#  ('postag[:2]:DA', 'B-LOC'): -0.287413,
#  ('postag[:2]:DA', 'O'): 0.713788,
#  ('postag[:2]:DA', 'B-ORG'): -0.275585,
#  ('postag[:2]:DA', 'B-PER'): -2.557981,
#  ('postag[:2]:DA', 'I-PER'): 0.387232,
#  ('postag[:2]:DA', 'B-MISC'): -0.398395,
#  ('postag[:2]:DA', 'I-ORG'): 0.049446,
#  ('postag[:2]:DA', 'I-LOC'): 0.301361,
#  ('postag[:2]:DA', 'I-MISC'): 0.124345,
#  ('word.lower():abogado', 'B-PER'): 2.458772,
#  ('word[-3:]:ado', 'B-LOC'): -0.303425,
#  ('word[-3:]:ado', 'O'): 0.352844,
#  ('word[-3:]:ado', 'B-ORG'): 0.453653,
#  ('word[-3:]:ado', 'B-PER'): -0.710265,
#  ('word[-3:]:ado', 'I-PER'): 0.381141,
#  ('word[-3:]:ado', 'B-MISC'): 0.004015,
#  ('word[-3:]:ado', 'I-ORG'): 0.200296,
#  ('word[-3:]:ado', 'I-LOC'): -0.575149,
#  ('word[-3:]:ado', 'I-MISC'): -0.123433,
#  ('word[-2:]:do', 'B-LOC'): -0.167442,
#  ('word[-2:]:do', 'O'): 0.436725,
#  ('word[-2:]:do', 'B-ORG'): -0.034594,
#  ('word[-2:]:do', 'B-PER'): 0.416256,
#  ('word[-2:]:do', 'I-PER'): -0.023743,
#  ('word[-2:]:do', 'B-MISC'): -0.140768,
#  ('word[-2:]:do', 'I-ORG'): 0.125482,
#  ('word[-2:]:do', 'I-LOC'): -0.136231,
#  ('word[-2:]:do', 'I-MISC'): -0.651596,
#  ('-1:word.lower():el', 'B-LOC'): -0.014115,
#  ('-1:word.lower():el', 'O'): -0.044509,
#  ('-1:word.lower():el', 'B-ORG'): 0.878885,
#  ('-1:word.lower():el', 'B-PER'): -1.246782,
#  ('-1:word.lower():el', 'I-PER'): 0.016243,
#  ('-1:word.lower():el', 'B-MISC'): 0.144252,
#  ('-1:word.lower():el', 'I-ORG'): 0.265847,
#  ('-1:word.lower():el', 'I-LOC'): -0.019879,
#  ('-1:word.lower():el', 'I-MISC'): 0.146437,
#  ('-1:postag:DA', 'B-LOC'): -0.18283,
#  ('-1:postag:DA', 'O'): -0.208494,
#  ('-1:postag:DA', 'B-ORG'): 0.314246,
#  ('-1:postag:DA', 'B-PER'): -0.846922,
#  ('-1:postag:DA', 'I-PER'): 1.43719,
#  ('-1:postag:DA', 'B-MISC'): 0.322141,
#  ('-1:postag:DA', 'I-ORG'): 1.004529,
#  ('-1:postag:DA', 'I-LOC'): 0.692395,
#  ('-1:postag:DA', 'I-MISC'): 0.649559,
#  ('-1:postag[:2]:DA', 'B-LOC'): -0.18283,
#  ('-1:postag[:2]:DA', 'O'): -0.208494,
#  ('-1:postag[:2]:DA', 'B-ORG'): 0.314246,
#  ('-1:postag[:2]:DA', 'B-PER'): -0.846922,
#  ('-1:postag[:2]:DA', 'I-PER'): 1.43719,
#  ('-1:postag[:2]:DA', 'B-MISC'): 0.322141,
#  ('-1:postag[:2]:DA', 'I-ORG'): 1.004529,
#  ('-1:postag[:2]:DA', 'I-LOC'): 0.692395,
#  ('-1:postag[:2]:DA', 'I-MISC'): 0.649559,
#  ('+1:word.lower():general', 'B-LOC'): 0.012434,
#  ('+1:word.lower():general', 'B-ORG'): -0.459818,
#  ('+1:word.lower():general', 'B-PER'): 1.196915,
#  ('+1:word.lower():general', 'B-MISC'): 0.159471,
#  ('+1:postag:AQ', 'B-LOC'): -0.324916,
#  ('+1:postag:AQ', 'O'): 0.860722,
#  ('+1:postag:AQ', 'B-ORG'): 0.010369,
#  ('+1:postag:AQ', 'B-PER'): -0.141305,
#  ('+1:postag:AQ', 'I-PER'): -0.545685,
#  ('+1:postag:AQ', 'B-MISC'): -0.060135,
#  ('+1:postag:AQ', 'I-ORG'): -0.222957,
#  ('+1:postag:AQ', 'I-LOC'): -0.227321,
#  ('+1:postag:AQ', 'I-MISC'): 0.152237,
#  ('+1:postag[:2]:AQ', 'B-LOC'): -0.324916,
#  ('+1:postag[:2]:AQ', 'O'): 0.860722,
#  ('+1:postag[:2]:AQ', 'B-ORG'): 0.010369,
#  ('+1:postag[:2]:AQ', 'B-PER'): -0.141305,
#  ('+1:postag[:2]:AQ', 'I-PER'): -0.545685,
#  ('+1:postag[:2]:AQ', 'B-MISC'): -0.060135,
#  ('+1:postag[:2]:AQ', 'I-ORG'): -0.222957,
#  ('+1:postag[:2]:AQ', 'I-LOC'): -0.227321,
#  ('+1:postag[:2]:AQ', 'I-MISC'): 0.152237,
#  ('word.lower():general', 'O'): -0.354415,
#  ('word.lower():general', 'I-PER'): 1.497444,
#  ('word.lower():general', 'I-ORG'): -2.030491,
#  ('word.lower():general', 'I-MISC'): 0.118412,
#  ('word[-3:]:ral', 'B-LOC'): 1.10346,
#  ('word[-3:]:ral', 'O'): -0.008847,
#  ('word[-3:]:ral', 'B-ORG'): -0.142212,
#  ('word[-3:]:ral', 'B-MISC'): 0.912692,
#  ('word[-3:]:ral', 'I-ORG'): -0.008542,
#  ('word[-3:]:ral', 'I-LOC'): 0.077057,
#  ('word[-3:]:ral', 'I-MISC'): 0.184442,
#  ('word[-2:]:al', 'B-LOC'): -0.240323,
#  ('word[-2:]:al', 'O'): 0.932756,
#  ('word[-2:]:al', 'B-ORG'): 0.227571,
#  ('word[-2:]:al', 'B-PER'): -1.632777,
#  ('word[-2:]:al', 'I-PER'): -1.108181,
#  ('word[-2:]:al', 'B-MISC'): 0.322554,
#  ('word[-2:]:al', 'I-ORG'): 0.453932,
#  ('word[-2:]:al', 'I-LOC'): 0.269257,
#  ('word[-2:]:al', 'I-MISC'): 0.555851,
#  ('postag:AQ', 'B-LOC'): 0.112731,
#  ('postag:AQ', 'O'): -0.308717,
#  ('postag:AQ', 'B-ORG'): 0.156147,
#  ('postag:AQ', 'B-PER'): 0.452777,
#  ('postag:AQ', 'I-PER'): 0.18292,
#  ('postag:AQ', 'B-MISC'): 0.126132,
#  ('postag:AQ', 'I-ORG'): 0.196966,
#  ('postag:AQ', 'I-LOC'): 0.113593,
#  ('postag:AQ', 'I-MISC'): 0.481265,
#  ('postag[:2]:AQ', 'B-LOC'): 0.112731,
#  ('postag[:2]:AQ', 'O'): -0.308717,
#  ('postag[:2]:AQ', 'B-ORG'): 0.156147,
#  ('postag[:2]:AQ', 'B-PER'): 0.452777,
#  ('postag[:2]:AQ', 'I-PER'): 0.18292,
#  ('postag[:2]:AQ', 'B-MISC'): 0.126132,
#  ('postag[:2]:AQ', 'I-ORG'): 0.196966,
#  ('postag[:2]:AQ', 'I-LOC'): 0.113593,
#  ('postag[:2]:AQ', 'I-MISC'): 0.481265,
#  ('-1:word.lower():abogado', 'I-PER'): 2.079314,
#  ('+1:word.lower():del', 'B-LOC'): 0.103078,
#  ('+1:word.lower():del', 'O'): 0.168571,
#  ('+1:word.lower():del', 'B-ORG'): -0.371725,
#  ('+1:word.lower():del', 'B-PER'): -0.332896,
#  ('+1:word.lower():del', 'I-PER'): -3.6141,
#  ('+1:word.lower():del', 'B-MISC'): 0.381781,
#  ('+1:word.lower():del', 'I-ORG'): -0.683248,
#  ('+1:word.lower():del', 'I-LOC'): -0.280413,
#  ('+1:word.lower():del', 'I-MISC'): 0.577922,
#  ('+1:postag:SP', 'B-LOC'): -0.078172,
#  ('+1:postag:SP', 'O'): 0.545764,
#  ('+1:postag:SP', 'B-ORG'): -0.163661,
#  ('+1:postag:SP', 'B-PER'): -0.253583,
#  ('+1:postag:SP', 'I-PER'): -0.248035,
#  ('+1:postag:SP', 'B-MISC'): -0.096614,
#  ('+1:postag:SP', 'I-ORG'): -0.066803,
#  ('+1:postag:SP', 'I-LOC'): 0.109973,
#  ('+1:postag:SP', 'I-MISC'): 0.169115,
#  ('+1:postag[:2]:SP', 'B-LOC'): -0.078172,
#  ('+1:postag[:2]:SP', 'O'): 0.545764,
#  ('+1:postag[:2]:SP', 'B-ORG'): -0.163661,
#  ('+1:postag[:2]:SP', 'B-PER'): -0.253583,
#  ('+1:postag[:2]:SP', 'I-PER'): -0.248035,
#  ('+1:postag[:2]:SP', 'B-MISC'): -0.096614,
#  ('+1:postag[:2]:SP', 'I-ORG'): -0.066803,
#  ('+1:postag[:2]:SP', 'I-LOC'): 0.109973,
#  ('+1:postag[:2]:SP', 'I-MISC'): 0.169115,
#  ('word.lower():del', 'O'): -0.751196,
#  ('word.lower():del', 'I-PER'): 0.290999,
#  ('word.lower():del', 'I-ORG'): 0.44158,
#  ('word.lower():del', 'I-LOC'): 0.39242,
#  ('word.lower():del', 'I-MISC'): -0.032118,
#  ('word[-3:]:del', 'O'): -0.601343,
#  ('word[-3:]:del', 'B-PER'): -1.237269,
#  ('word[-3:]:del', 'I-PER'): 0.639964,
#  ('word[-3:]:del', 'I-ORG'): 0.442434,
#  ('word[-3:]:del', 'I-LOC'): 0.46795,
#  ('word[-3:]:del', 'I-MISC'): -0.009447,
#  ('word[-2:]:el', 'B-LOC'): -0.211274,
#  ('word[-2:]:el', 'O'): -0.73712,
#  ('word[-2:]:el', 'B-ORG'): -0.09191,
#  ('word[-2:]:el', 'B-PER'): 0.469918,
#  ('word[-2:]:el', 'I-PER'): 0.357623,
#  ('word[-2:]:el', 'B-MISC'): -1.782938,
#  ('word[-2:]:el', 'I-ORG'): 0.201343,
#  ('word[-2:]:el', 'I-LOC'): 0.53499,
#  ('word[-2:]:el', 'I-MISC'): 0.143343,
#  ('postag:SP', 'B-LOC'): -1.65463,
#  ('postag:SP', 'O'): 1.381237,
#  ('postag:SP', 'B-ORG'): -1.866609,
#  ('postag:SP', 'B-PER'): -1.965197,
#  ('postag:SP', 'I-PER'): 0.153498,
#  ('postag:SP', 'B-MISC'): -2.194206,
#  ('postag:SP', 'I-ORG'): -0.265708,
#  ('postag:SP', 'I-LOC'): 0.139367,
#  ('postag:SP', 'I-MISC'): -0.112229,
#  ('postag[:2]:SP', 'B-LOC'): -1.65463,
#  ('postag[:2]:SP', 'O'): 1.381237,
#  ('postag[:2]:SP', 'B-ORG'): -1.866609,
#  ('postag[:2]:SP', 'B-PER'): -1.965197,
#  ('postag[:2]:SP', 'I-PER'): 0.153498,
#  ('postag[:2]:SP', 'B-MISC'): -2.194206,
#  ('postag[:2]:SP', 'I-ORG'): -0.265708,
#  ('postag[:2]:SP', 'I-LOC'): 0.139367,
#  ('postag[:2]:SP', 'I-MISC'): -0.112229,
#  ('-1:word.lower():general', 'O'): 0.291643,
#  ('-1:word.lower():general', 'B-PER'): 1.039255,
#  ('-1:word.lower():general', 'I-PER'): 0.318488,
#  ('-1:word.lower():general', 'I-ORG'): 1.543408,
#  ('-1:word.lower():general', 'I-MISC'): -0.072367,
#  ('-1:postag:AQ', 'B-LOC'): -0.03245,
#  ('-1:postag:AQ', 'O'): 0.193747,
#  ('-1:postag:AQ', 'B-ORG'): 0.05879,
#  ('-1:postag:AQ', 'B-PER'): -0.129051,
#  ('-1:postag:AQ', 'I-PER'): 0.51617,
#  ('-1:postag:AQ', 'B-MISC'): 0.031012,
#  ('-1:postag:AQ', 'I-ORG'): -0.072663,
#  ('-1:postag:AQ', 'I-LOC'): 0.144145,
#  ('-1:postag:AQ', 'I-MISC'): 0.180021,
#  ('-1:postag[:2]:AQ', 'B-LOC'): -0.03245,
#  ('-1:postag[:2]:AQ', 'O'): 0.193747,
#  ('-1:postag[:2]:AQ', 'B-ORG'): 0.05879,
#  ('-1:postag[:2]:AQ', 'B-PER'): -0.129051,
#  ('-1:postag[:2]:AQ', 'I-PER'): 0.51617,
#  ('-1:postag[:2]:AQ', 'B-MISC'): 0.031012,
#  ('-1:postag[:2]:AQ', 'I-ORG'): -0.072663,
#  ('-1:postag[:2]:AQ', 'I-LOC'): 0.144145,
#  ('-1:postag[:2]:AQ', 'I-MISC'): 0.180021,
#  ('+1:word.lower():estado', 'O'): -1.429141,
#  ('+1:word.lower():estado', 'I-PER'): 0.328241,
#  ('+1:word.lower():estado', 'I-ORG'): 0.435043,
#  ('+1:word.lower():estado', 'I-MISC'): 0.31291,
#  ('word.lower():estado', 'O'): 1.227994,
#  ('word.lower():estado', 'B-ORG'): 3.732585,
#  ('word.lower():estado', 'B-MISC'): 0.060241,
#  ('word.lower():estado', 'I-ORG'): 0.43583,
#  ('word.lower():estado', 'I-MISC'): 0.730121,
#  ('-1:word.lower():del', 'B-LOC'): -1.270738,
#  ('-1:word.lower():del', 'O'): -0.089883,
#  ('-1:word.lower():del', 'B-ORG'): 0.59172,
#  ('-1:word.lower():del', 'B-PER'): -4.066255,
#  ('-1:word.lower():del', 'I-PER'): 2.982342,
#  ('-1:word.lower():del', 'B-MISC'): 1.143684,
#  ('-1:word.lower():del', 'I-ORG'): 0.283851,
#  ('-1:word.lower():del', 'I-LOC'): 0.393564,
#  ('-1:word.lower():del', 'I-MISC'): 0.189947,
#  ('-1:postag:SP', 'B-LOC'): -0.145134,
#  ('-1:postag:SP', 'O'): -0.578691,
#  ('-1:postag:SP', 'B-ORG'): -0.053076,
#  ('-1:postag:SP', 'B-PER'): -0.435951,
#  ('-1:postag:SP', 'I-PER'): 0.669088,
#  ('-1:postag:SP', 'B-MISC'): -0.272219,
#  ('-1:postag:SP', 'I-ORG'): 1.061303,
#  ('-1:postag:SP', 'I-LOC'): 0.887789,
#  ('-1:postag:SP', 'I-MISC'): 0.744014,
#  ('-1:postag[:2]:SP', 'B-LOC'): -0.145134,
#  ('-1:postag[:2]:SP', 'O'): -0.578691,
#  ('-1:postag[:2]:SP', 'B-ORG'): -0.053076,
#  ('-1:postag[:2]:SP', 'B-PER'): -0.435951,
#  ('-1:postag[:2]:SP', 'I-PER'): 0.669088,
#  ('-1:postag[:2]:SP', 'B-MISC'): -0.272219,
#  ('-1:postag[:2]:SP', 'I-ORG'): 1.061303,
#  ('-1:postag[:2]:SP', 'I-LOC'): 0.887789,
#  ('-1:postag[:2]:SP', 'I-MISC'): 0.744014,
#  ('-1:word.lower():estado', 'O'): 1.837217,
#  ('-1:word.lower():estado', 'I-ORG'): -0.316954,
#  ('-1:word.lower():estado', 'I-MISC'): 0.551511,
#  ('+1:postag:VMI', 'B-LOC'): 0.006363,
#  ('+1:postag:VMI', 'O'): -0.603318,
#  ('+1:postag:VMI', 'B-ORG'): 0.049823,
#  ('+1:postag:VMI', 'B-PER'): 0.782757,
#  ('+1:postag:VMI', 'I-PER'): 0.003239,
#  ('+1:postag:VMI', 'B-MISC'): -0.267171,
#  ('+1:postag:VMI', 'I-ORG'): 0.061793,
#  ('+1:postag:VMI', 'I-LOC'): -0.0748,
#  ('+1:postag:VMI', 'I-MISC'): -0.094635,
#  ('+1:postag[:2]:VM', 'B-LOC'): -0.471235,
#  ('+1:postag[:2]:VM', 'O'): 0.237687,
#  ('+1:postag[:2]:VM', 'B-ORG'): 0.222616,
#  ('+1:postag[:2]:VM', 'B-PER'): 0.228104,
#  ('+1:postag[:2]:VM', 'I-PER'): 0.208625,
#  ('+1:postag[:2]:VM', 'B-MISC'): -0.466113,
#  ('+1:postag[:2]:VM', 'I-ORG'): -0.1089,
#  ('+1:postag[:2]:VM', 'I-LOC'): -0.313154,
#  ('+1:postag[:2]:VM', 'I-MISC'): -0.346888,
#  ('word[-2:]:yl', 'B-ORG'): 0.481673,
#  ('postag:VMI', 'B-LOC'): 0.32006,
#  ('postag:VMI', 'O'): -0.026864,
#  ('postag:VMI', 'B-ORG'): 0.714827,
#  ('postag:VMI', 'B-PER'): 0.952809,
#  ('postag:VMI', 'I-PER'): -0.436208,
#  ('postag:VMI', 'B-MISC'): -0.162061,
#  ('postag:VMI', 'I-ORG'): -0.195508,
#  ('postag:VMI', 'I-LOC'): 0.067411,
#  ('postag:VMI', 'I-MISC'): -0.216813,
#  ('postag[:2]:VM', 'B-LOC'): 0.156809,
#  ('postag[:2]:VM', 'O'): 0.102147,
#  ('postag[:2]:VM', 'B-ORG'): 0.059419,
#  ('postag[:2]:VM', 'B-PER'): 0.499292,
#  ('postag[:2]:VM', 'I-PER'): -0.703537,
#  ('postag[:2]:VM', 'B-MISC'): -0.226193,
#  ('postag[:2]:VM', 'I-ORG'): -0.921638,
#  ('postag[:2]:VM', 'I-LOC'): 0.014888,
#  ('postag[:2]:VM', 'I-MISC'): -0.094572,
#  ('+1:word.lower():williams', 'B-PER'): 0.125986,
#  ('word.lower():williams', 'B-ORG'): 2.064838,
#  ('word.lower():williams', 'I-PER'): 0.140537,
#  ('word[-3:]:ams', 'B-ORG'): 1.992084,
#  ('word[-3:]:ams', 'I-PER'): 2.37838,
#  ('word[-2:]:ms', 'B-ORG'): 1.665707,
#  ('-1:postag:VMI', 'B-LOC'): -0.285996,
#  ('-1:postag:VMI', 'O'): -0.490079,
#  ('-1:postag:VMI', 'B-ORG'): 0.046096,
#  ('-1:postag:VMI', 'B-PER'): 0.398994,
#  ('-1:postag:VMI', 'I-PER'): 0.372691,
#  ('-1:postag:VMI', 'B-MISC'): -0.203444,
#  ('-1:postag:VMI', 'I-ORG'): -0.417478,
#  ('-1:postag:VMI', 'I-LOC'): -0.070545,
#  ('-1:postag:VMI', 'I-MISC'): -0.018761,
#  ('-1:postag[:2]:VM', 'B-LOC'): -0.608909,
#  ('-1:postag[:2]:VM', 'O'): 0.16652,
#  ('-1:postag[:2]:VM', 'B-ORG'): -0.719141,
#  ('-1:postag[:2]:VM', 'B-PER'): 0.374914,
#  ('-1:postag[:2]:VM', 'I-PER'): 0.484656,
#  ('-1:postag[:2]:VM', 'B-MISC'): -0.293145,
#  ('-1:postag[:2]:VM', 'I-ORG'): -0.262717,
#  ('-1:postag[:2]:VM', 'I-LOC'): -0.074732,
#  ('-1:postag[:2]:VM', 'I-MISC'): 0.434922,
#  ('-1:word.lower():williams', 'I-ORG'): 5.8e-05,
#  ('+1:word.lower():subrayó', 'B-PER'): 1.066579,
#  ('word[-3:]:ayó', 'O'): 0.534779,
#  ('word[-2:]:yó', 'O'): 1.111806,
#  ('+1:word.lower():hoy', 'B-ORG'): 1.342585,
#  ('+1:postag:RG', 'B-LOC'): -0.041107,
#  ('+1:postag:RG', 'O'): 0.534149,
#  ('+1:postag:RG', 'B-ORG'): 0.008023,
#  ('+1:postag:RG', 'I-PER'): -0.124636,
#  ('+1:postag:RG', 'B-MISC'): -0.216793,
#  ('+1:postag:RG', 'I-LOC'): -0.166659,
#  ('+1:postag:RG', 'I-MISC'): 0.085418,
#  ('+1:postag[:2]:RG', 'B-LOC'): -0.041107,
#  ('+1:postag[:2]:RG', 'O'): 0.534149,
#  ('+1:postag[:2]:RG', 'B-ORG'): 0.008023,
#  ('+1:postag[:2]:RG', 'I-PER'): -0.124636,
#  ('+1:postag[:2]:RG', 'B-MISC'): -0.216793,
#  ('+1:postag[:2]:RG', 'I-LOC'): -0.166659,
#  ('+1:postag[:2]:RG', 'I-MISC'): 0.085418,
#  ('word.lower():hoy', 'O'): -0.036754,
#  ('word.lower():hoy', 'I-ORG'): 3.431823,
#  ('word[-2:]:oy', 'O'): 1.242545,
#  ('word[-2:]:oy', 'B-PER'): 0.289467,
#  ('postag:RG', 'O'): 2.181852,
#  ('postag:RG', 'B-PER'): -0.42781,
#  ('postag:RG', 'I-PER'): -0.138752,
#  ('postag:RG', 'I-MISC'): 1.412294,
#  ('postag[:2]:RG', 'O'): 2.181852,
#  ('postag[:2]:RG', 'B-PER'): -0.42781,
#  ('postag[:2]:RG', 'I-PER'): -0.138752,
#  ('postag[:2]:RG', 'I-MISC'): 1.412294,
#  ('-1:word.lower():subrayó', 'O'): -0.298781,
#  ('-1:word.lower():subrayó', 'B-PER'): 1.285085,
#  ('+1:word.lower():la', 'B-LOC'): -0.81517,
#  ('+1:word.lower():la', 'O'): 0.336003,
#  ('+1:word.lower():la', 'B-ORG'): 0.122105,
#  ('+1:word.lower():la', 'B-PER'): 0.401903,
#  ('+1:word.lower():la', 'I-PER'): -0.554645,
#  ('+1:word.lower():la', 'B-MISC'): 0.002352,
#  ('+1:word.lower():la', 'I-ORG'): -0.101709,
#  ('+1:word.lower():la', 'I-LOC'): 0.309481,
#  ('+1:word.lower():la', 'I-MISC'): 0.177625,
#  ('+1:postag:DA', 'B-LOC'): 0.142329,
#  ('+1:postag:DA', 'O'): 0.334377,
#  ('+1:postag:DA', 'B-ORG'): -0.029187,
#  ('+1:postag:DA', 'B-PER'): -0.134747,
#  ('+1:postag:DA', 'I-PER'): -0.137187,
#  ('+1:postag:DA', 'B-MISC'): -0.203655,
#  ('+1:postag:DA', 'I-ORG'): 0.042673,
#  ('+1:postag:DA', 'I-LOC'): 0.305808,
#  ('+1:postag:DA', 'I-MISC'): 0.144292,
#  ('+1:postag[:2]:DA', 'B-LOC'): 0.142329,
#  ('+1:postag[:2]:DA', 'O'): 0.334377,
#  ('+1:postag[:2]:DA', 'B-ORG'): -0.029187,
#  ('+1:postag[:2]:DA', 'B-PER'): -0.134747,
#  ('+1:postag[:2]:DA', 'I-PER'): -0.137187,
#  ('+1:postag[:2]:DA', 'B-MISC'): -0.203655,
#  ('+1:postag[:2]:DA', 'I-ORG'): 0.042673,
#  ('+1:postag[:2]:DA', 'I-LOC'): 0.305808,
#  ('+1:postag[:2]:DA', 'I-MISC'): 0.144292,
#  ('word.lower():la', 'B-LOC'): -0.001623,
#  ('word.lower():la', 'O'): 0.23384,
#  ('word.lower():la', 'B-ORG'): -0.087866,
#  ('word.lower():la', 'B-PER'): -0.307884,
#  ('word.lower():la', 'I-PER'): 0.4413,
#  ('word.lower():la', 'B-MISC'): -0.339906,
#  ('word.lower():la', 'I-ORG'): 0.147951,
#  ('word.lower():la', 'I-LOC'): 0.165934,
#  ('word.lower():la', 'I-MISC'): 0.093704,
#  ('word[-3:]:la', 'B-LOC'): -2.621498,
#  ('word[-3:]:la', 'O'): -0.299497,
#  ('word[-3:]:la', 'B-ORG'): 0.218837,
#  ('word[-3:]:la', 'I-PER'): 0.601111,
#  ('word[-3:]:la', 'I-ORG'): 0.610458,
#  ('word[-3:]:la', 'I-LOC'): 0.526035,
#  ('word[-3:]:la', 'I-MISC'): 0.282289,
#  ('word[-2:]:la', 'B-LOC'): 0.499112,
#  ('word[-2:]:la', 'O'): -0.086745,
#  ('word[-2:]:la', 'B-ORG'): -0.029486,
#  ('word[-2:]:la', 'B-PER'): -0.634749,
#  ('word[-2:]:la', 'I-PER'): 0.677967,
#  ('word[-2:]:la', 'B-MISC'): -0.833622,
#  ('word[-2:]:la', 'I-ORG'): 0.331168,
#  ('word[-2:]:la', 'I-LOC'): 0.950753,
#  ('word[-2:]:la', 'I-MISC'): 0.204319,
#  ('-1:word.lower():hoy', 'B-LOC'): 0.150298,
#  ('-1:word.lower():hoy', 'O'): -0.0872,
#  ('-1:word.lower():hoy', 'B-ORG'): -1.510208,
#  ('-1:word.lower():hoy', 'I-ORG'): 1.84588,
#  ('-1:postag:RG', 'O'): -0.091764,
#  ('-1:postag:RG', 'B-ORG'): 0.012447,
#  ('-1:postag:RG', 'B-PER'): -0.105021,
#  ('-1:postag:RG', 'B-MISC'): -0.189131,
#  ('-1:postag:RG', 'I-ORG'): 0.451638,
#  ('-1:postag:RG', 'I-MISC'): 1.296795,
#  ('-1:postag[:2]:RG', 'O'): -0.091764,
#  ('-1:postag[:2]:RG', 'B-ORG'): 0.012447,
#  ('-1:postag[:2]:RG', 'B-PER'): -0.105021,
#  ('-1:postag[:2]:RG', 'B-MISC'): -0.189131,
#  ('-1:postag[:2]:RG', 'I-ORG'): 0.451638,
#  ('-1:postag[:2]:RG', 'I-MISC'): 1.296795,
#  ('word[-3:]:dad', 'B-LOC'): -0.057397,
#  ('word[-3:]:dad', 'O'): 0.530162,
#  ('word[-3:]:dad', 'B-ORG'): -0.017795,
#  ('word[-3:]:dad', 'B-PER'): -2.065918,
#  ('word[-3:]:dad', 'I-PER'): -0.187458,
#  ('word[-3:]:dad', 'B-MISC'): 0.432742,
#  ('word[-3:]:dad', 'I-ORG'): -0.079437,
#  ('word[-3:]:dad', 'I-LOC'): -0.506176,
#  ('word[-3:]:dad', 'I-MISC'): 0.322137,
#  ('word[-2:]:ad', 'B-LOC'): -0.006503,
#  ('word[-2:]:ad', 'O'): 0.645807,
#  ('word[-2:]:ad', 'B-ORG'): -0.022054,
#  ('word[-2:]:ad', 'B-PER'): -0.468434,
#  ('word[-2:]:ad', 'I-PER'): -0.117645,
#  ('word[-2:]:ad', 'B-MISC'): 0.128093,
#  ('word[-2:]:ad', 'I-ORG'): -0.003171,
#  ('word[-2:]:ad', 'I-LOC'): -1.051524,
#  ('word[-2:]:ad', 'I-MISC'): 0.115422,
#  ('-1:word.lower():la', 'B-LOC'): 0.011407,
#  ('-1:word.lower():la', 'O'): -0.11977,
#  ('-1:word.lower():la', 'B-ORG'): 0.185047,
#  ('-1:word.lower():la', 'B-PER'): -1.163925,
#  ('-1:word.lower():la', 'I-PER'): 1.809411,
#  ('-1:word.lower():la', 'B-MISC'): -0.09042,
#  ('-1:word.lower():la', 'I-ORG'): 0.570418,
#  ('-1:word.lower():la', 'I-LOC'): 1.046156,
#  ('-1:word.lower():la', 'I-MISC'): 0.471604,
#  ('+1:word.lower():de', 'B-LOC'): -0.05544,
#  ('+1:word.lower():de', 'O'): 0.467127,
#  ('+1:word.lower():de', 'B-ORG'): -0.349017,
#  ('+1:word.lower():de', 'B-PER'): -0.375294,
#  ('+1:word.lower():de', 'I-PER'): -0.520236,
#  ('+1:word.lower():de', 'B-MISC'): 0.308269,
#  ('+1:word.lower():de', 'I-ORG'): -0.225794,
#  ('+1:word.lower():de', 'I-LOC'): 0.550097,
#  ('+1:word.lower():de', 'I-MISC'): 0.255866,
#  ('word.lower():de', 'O'): -0.254513,
#  ('word.lower():de', 'B-PER'): 0.648161,
#  ('word.lower():de', 'I-PER'): 0.559532,
#  ('word.lower():de', 'I-ORG'): 0.58407,
#  ('word.lower():de', 'I-LOC'): 0.529384,
#  ('word.lower():de', 'I-MISC'): 0.394537,
#  ('word[-3:]:de', 'O'): -0.309725,
#  ('word[-3:]:de', 'B-ORG'): 0.298667,
#  ('word[-3:]:de', 'B-PER'): 0.005458,
#  ('word[-3:]:de', 'I-PER'): 0.56751,
#  ('word[-3:]:de', 'I-ORG'): 0.637333,
#  ('word[-3:]:de', 'I-LOC'): 0.548908,
#  ('word[-3:]:de', 'I-MISC'): 0.389474,
#  ('word[-2:]:de', 'B-LOC'): -0.646105,
#  ('word[-2:]:de', 'O'): -0.280956,
#  ('word[-2:]:de', 'B-ORG'): -0.838356,
#  ('word[-2:]:de', 'B-PER'): 0.100345,
#  ('word[-2:]:de', 'I-PER'): 0.545266,
#  ('word[-2:]:de', 'I-ORG'): 0.558499,
#  ('word[-2:]:de', 'I-LOC'): 0.619938,
#  ('word[-2:]:de', 'I-MISC'): 0.432188,
#  ('+1:postag:VMN', 'B-LOC'): -0.402931,
#  ('+1:postag:VMN', 'O'): 1.499577,
#  ('+1:postag:VMN', 'I-PER'): -0.055721,
#  ('+1:postag:VMN', 'I-ORG'): -0.0404,
#  ('+1:postag:VMN', 'I-MISC'): -0.023974,
#  ('word[-3:]:mar', 'O'): -0.034287,
#  ('word[-3:]:mar', 'B-ORG'): 0.400685,
#  ('word[-3:]:mar', 'I-MISC'): 0.741237,
#  ('word[-2:]:ar', 'B-LOC'): 0.3634,
#  ('word[-2:]:ar', 'O'): 1.026101,
#  ('word[-2:]:ar', 'B-ORG'): -0.736768,
#  ('word[-2:]:ar', 'B-PER'): 0.272919,
#  ('word[-2:]:ar', 'I-PER'): 0.068829,
#  ('word[-2:]:ar', 'B-MISC'): -0.982276,
#  ('word[-2:]:ar', 'I-ORG'): -0.650492,
#  ('word[-2:]:ar', 'I-LOC'): 0.083251,
#  ('word[-2:]:ar', 'I-MISC'): -0.04564,
#  ('postag:VMN', 'B-LOC'): -0.006557,
#  ('postag:VMN', 'O'): -0.170337,
#  ('postag:VMN', 'B-ORG'): -0.731695,
#  ('postag:VMN', 'B-PER'): -0.001119,
#  ('postag:VMN', 'B-MISC'): -0.505834,
#  ('postag:VMN', 'I-ORG'): 0.109499,
#  ('postag:VMN', 'I-LOC'): -0.000329,
#  ('postag:VMN', 'I-MISC'): 0.189984,
#  ('-1:word.lower():de', 'B-LOC'): -0.186197,
#  ('-1:word.lower():de', 'O'): -0.85646,
#  ('-1:word.lower():de', 'B-ORG'): -1.372407,
#  ('-1:word.lower():de', 'B-PER'): -1.256531,
#  ('-1:word.lower():de', 'I-PER'): 2.781428,
#  ('-1:word.lower():de', 'B-MISC'): -0.144913,
#  ('-1:word.lower():de', 'I-ORG'): 1.381949,
#  ('-1:word.lower():de', 'I-LOC'): 1.291355,
#  ('-1:word.lower():de', 'I-MISC'): 0.815047,
#  ('word[-3:]:das', 'B-LOC'): 1.32882,
#  ('word[-3:]:das', 'O'): 2.329997,
#  ('word[-3:]:das', 'I-PER'): -0.028221,
#  ('word[-3:]:das', 'B-MISC'): 0.559251,
#  ('word[-3:]:das', 'I-ORG'): 0.054517,
#  ('word[-3:]:das', 'I-MISC'): 0.015302,
#  ('word[-2:]:as', 'B-LOC'): -0.947298,
#  ('word[-2:]:as', 'O'): 0.510756,
#  ('word[-2:]:as', 'B-ORG'): -0.344556,
#  ('word[-2:]:as', 'B-PER'): -0.463424,
#  ('word[-2:]:as', 'I-PER'): -0.079238,
#  ('word[-2:]:as', 'B-MISC'): -0.172916,
#  ('word[-2:]:as', 'I-ORG'): 0.224038,
#  ('word[-2:]:as', 'I-LOC'): -0.265956,
#  ('word[-2:]:as', 'I-MISC'): 0.318592,
#  ('-1:postag:VMN', 'B-LOC'): -0.355669,
#  ('-1:postag:VMN', 'O'): 1.20901,
#  ('-1:postag:VMN', 'B-ORG'): 0.024656,
#  ('-1:postag:VMN', 'B-PER'): 0.168312,
#  ('-1:postag:VMN', 'I-PER'): -0.781068,
#  ('-1:postag:VMN', 'I-ORG'): -0.068332,
#  ('-1:postag:VMN', 'I-LOC'): -0.547474,
#  ('-1:postag:VMN', 'I-MISC'): 0.56459,
#  ('+1:word.lower():para', 'B-LOC'): 0.403456,
#  ('+1:word.lower():para', 'O'): -0.394573,
#  ('+1:word.lower():para', 'B-ORG'): 0.492877,
#  ('+1:word.lower():para', 'B-PER'): -0.542732,
#  ('+1:word.lower():para', 'B-MISC'): -0.130128,
#  ('+1:word.lower():para', 'I-ORG'): 0.098224,
#  ('+1:word.lower():para', 'I-LOC'): 0.410432,
#  ('+1:word.lower():para', 'I-MISC'): -0.994313,
#  ('word.lower():para', 'O'): 0.346101,
#  ('word.lower():para', 'I-ORG'): 0.589023,
#  ('word.lower():para', 'I-MISC'): 0.277735,
#  ('word[-3:]:ara', 'B-LOC'): 0.062658,
#  ('word[-3:]:ara', 'O'): 0.003587,
#  ('word[-3:]:ara', 'B-ORG'): 0.224875,
#  ('word[-3:]:ara', 'B-PER'): -1.160355,
#  ('word[-3:]:ara', 'I-PER'): -0.768197,
#  ('word[-3:]:ara', 'B-MISC'): -0.998818,
#  ('word[-3:]:ara', 'I-ORG'): 0.718594,
#  ('word[-3:]:ara', 'I-LOC'): 0.139004,
#  ('word[-3:]:ara', 'I-MISC'): -0.046151,
#  ('word[-2:]:ra', 'O'): 0.33759,
#  ('word[-2:]:ra', 'B-ORG'): -0.80647,
#  ('word[-2:]:ra', 'B-PER'): -0.081606,
#  ('word[-2:]:ra', 'I-PER'): -0.130465,
#  ('word[-2:]:ra', 'B-MISC'): 0.002012,
#  ('word[-2:]:ra', 'I-ORG'): 0.285756,
#  ('word[-2:]:ra', 'I-LOC'): 0.001144,
#  ('word[-2:]:ra', 'I-MISC'): 0.022075,
#  ('word[-3:]:ger', 'B-PER'): 0.246731,
#  ('word[-2:]:er', 'B-LOC'): -0.83519,
#  ('word[-2:]:er', 'B-ORG'): -0.014567,
#  ('word[-2:]:er', 'B-PER'): 1.056547,
#  ('word[-2:]:er', 'I-PER'): 0.815413,
#  ('word[-2:]:er', 'B-MISC'): -0.342102,
#  ('word[-2:]:er', 'I-ORG'): -0.477133,
#  ('word[-2:]:er', 'I-LOC'): -1.242194,
#  ('word[-2:]:er', 'I-MISC'): 0.547493,
#  ('-1:word.lower():para', 'B-LOC'): 0.150919,
#  ('-1:word.lower():para', 'O'): -1.12068,
#  ('-1:word.lower():para', 'B-ORG'): 0.061663,
#  ('-1:word.lower():para', 'B-PER'): 2.027787,
#  ('-1:word.lower():para', 'I-ORG'): 0.975263,
#  ('-1:word.lower():para', 'I-MISC'): 0.952904,
#  ('+1:word.lower():al', 'B-LOC'): -0.437409,
#  ('+1:word.lower():al', 'O'): 0.159007,
#  ...}

# %%
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))    

print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(30))

print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-30:])
# Out:
# Top positive:
# 9.810583 B-ORG    word.lower():efe-cantabria
# 8.587255 B-ORG    word.lower():psoe-progresistas
# 6.026318 I-ORG    -1:word.lower():l
# 4.902771 B-ORG    word.lower():xfera
# 4.896558 B-LOC    -1:word.lower():cantabria
# 4.867565 O        BOS
# 4.810829 B-LOC    word.lower():líbano
# 4.760313 B-ORG    word.lower():telefónica
# 4.723549 B-MISC   word.lower():justicia
# 4.674730 B-ORG    word[-2:]:-e
# 4.597672 B-MISC   word.lower():competencia
# 4.582394 O        word.lower():r.
# 4.582394 O        word[-3:]:R.
# 4.545455 B-MISC   word.lower():diversia
# 4.409233 B-ORG    word.lower():petrobras
# 4.277603 B-ORG    word.lower():coag-extremadura
# 4.261705 B-PER    -1:word.lower():según
# 4.229368 I-LOC    -1:word.lower():calle
# 4.223481 B-ORG    word.isupper()
# 4.189817 B-ORG    word.lower():esquerra
# 4.188726 B-PER    word.lower():valedor
# 4.156011 O        word.lower():b
# 4.156011 O        word[-3:]:B
# 4.156011 O        word[-2:]:B
# 4.150794 B-ORG    word.lower():terra
# 4.121745 B-ORG    -1:word.lower():distancia
# 4.063192 B-LOC    -1:word.lower():celebrarán
# 4.043389 I-ORG    -1:word.lower():rasd
# 4.017850 B-ORG    +1:word.lower():plasencia
# 3.944671 B-MISC   word.lower():exteriores
#
# Top negative:
# -1.934899 B-MISC   word.lower():tribunal
# -1.941387 B-LOC    word[-3:]:ión
# -1.998870 O        postag:NP
# -1.998870 O        postag[:2]:NP
# -1.999583 B-PER    word[-2:]:os
# -2.005460 B-PER    word[-2:]:ón
# -2.040716 B-LOC    word[-3:]:la
# -2.043386 I-LOC    BOS
# -2.056432 O        -1:word.lower():agora
# -2.076812 I-PER    +1:word.lower():el
# -2.125426 O        -1:word.lower():británica
# -2.136499 O        +1:word.lower():justicia
# -2.170635 O        word.lower():061
# -2.183942 I-PER    +1:word.lower():del
# -2.189562 B-MISC   -1:word.isupper()
# -2.389167 O        word[-3:]:bas
# -2.421343 B-PER    word[-3:]:nes
# -2.423597 O        +1:word.lower():plasencia
# -2.425600 O        -1:word.lower():sección
# -2.426862 O        word[-2:]:nd
# -2.456323 O        word[-3:]:730
# -2.706624 O        word[-3:]:LOS
# -3.051235 O        word.lower():mas
# -3.053493 O        -1:word.lower():españolas
# -3.229068 I-PER    -1:word.lower():san
# -3.444361 B-PER    -1:word.lower():del
# -3.911123 O        -1:word.lower():celebrarán
# -4.310235 O        word[-2:]:om
# -5.999096 O        word.isupper()
# -8.285736 O        word.istitle()

# %% [markdown]
# Some observations:
#
#    * **9.385823 B-ORG word.lower():psoe-progresistas** - the model remembered names of some entities - maybe it is overfit, or maybe our features are not adequate, or maybe remembering is indeed helpful;
#    * **4.636151 I-LOC -1:word.lower():calle:** "calle" is a street in Spanish; model learns that if a previous word was "calle" then the token is likely a part of location;
#    * **-5.632036 O word.isupper()**, **-8.215073 O word.istitle()** : UPPERCASED or TitleCased words are likely entities of some kind;
#    * **-2.097561 O postag:NP** - proper nouns (NP is a proper noun in the Spanish tagset) are often entities.
#
# What to do next
#
#     * Load 'testa' Spanish data.
#     * Use it to develop better features and to find best model parameters.
#     * Apply the model to 'testb' data again.
#
# The model in this notebook is just a starting point; you certainly can do better!
